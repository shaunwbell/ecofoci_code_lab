# %% [markdown]
# # Using EcoFOCIpy to process raw field data
#
# **Cruise NW2101 (Spring Mooring Cruise)
#
# **Processed by Shaun Bell**
#
# ## CTD / Profile Data
#
# Basic workflow for each instrument grouping is *(initial archive level)*:
# - SBE workflow must happen first **done (performed on seperate windows system to convert to cnv)**
# - output initial files (pandas->csv) **ERDDAP NRT** when no meta data is added.  Good for quick analysis
#
# Other than hosting on an erddap server, the above can be done at sea
#
# For furthur processing, QC and archiving, the following tasks are to be done *(working or final data level)*:
# - Add metadata from cruise yaml files created from cast logs
# - apply any calibrations or corrections
#     + field corrections
#     + offsets
#     + spike analysis
#     + some QC were available... this would be old-school simple bounds mostly
# - save as CF netcdf via xarray or potentially csv file: so many of the steps above are optional
#     + **ERDDAP NRT** if no corrections, offsets or time bounds are applied but some meta data is (can be csv as this is useful at sea)
#     + **Working and awaiting QC** has no ERDDAP representation and is a holding spot
#     + **ERDDAP Final** fully calibrated, qc'd and populated with meta information
#
# Plot for preview and QC
# - TSSigma, TOXYChlor, TurbParTrans

# %%
import yaml
import glob

import ecofocipy.io.sbe_ctd_parser as sbe_ctd_parser #<- instrument specific
import ecofocipy.io.ncCFsave as ncCFsave
import ecofocipy.metaconfig.load_config as load_config
import ecofocipy.math.geotools as geotools

# %% [markdown]
# ## At Sea NRT Processing

# %%
sample_data_dir = '/Users/bell/ecoraid/2021/CTDcasts/nw2101/' #root path to cruise directory
ecofocipy_dir = '/Users/bell/Programs/EcoFOCIpy/'

# %%
###############################################################
# edit to point to {cruise sepcific} raw datafiles 
datafile = sample_data_dir+'rawconverted/' #<- point to cruise and process all files within
cruise_name = 'NW2101' #no hyphens
inst_meta_file = sample_data_dir+'logs/EMA_standard_CTD.yaml'
###############################################################

#init and load data
cruise = sbe_ctd_parser.sbe9_11p()
filename_list = sorted(glob.glob(datafile + '*.cnv'))

(cruise_data,cruise_header) = cruise.parse(filename_list)

# %%
#this line adds available NMEA data to csv files for NRT/Preliminary erddap hosting... if there isn't an NMEA string, you will have to pull the locations
#  from the cast logs and output either a .nc or a more elaborate csv file furthur in to this process
NMEA_location = False
verbose = True

if NMEA_location:
    
    for cast in cruise_header.keys():
        cruise_data[cast][['time','latitude','longitude','profileid']] = ('0',0,0,'0')
        cruise_data[cast][['time','latitude','longitude','profileid']] = (cruise_header[cast]['NMEAtime'],
              geotools.latlon_convert(cruise_header[cast]['NMEALat'],cruise_header[cast]['NMEALon'])[0],
              geotools.latlon_convert(cruise_header[cast]['NMEALat'],cruise_header[cast]['NMEALon'])[1],
              cast.split('.')[0])
        if verbose:
            print(cruise_header[cast]['NMEAtime'],
                  geotools.latlon_convert(cruise_header[cast]['NMEALat'],cruise_header[cast]['NMEALon'])[0],
                  geotools.latlon_convert(cruise_header[cast]['NMEALat'],cruise_header[cast]['NMEALon'])[1])

# %%
#save downcast csv to file for viewing - really this is just a cleaned up cnv file
import pandas as pd
for cast in cruise_data.keys():
#     print(f'Processing Cast {cast}')
    # cruise_data[cast]['time'] = pd.to_datetime(cruise_data[cast]['time'])
    cruise_data[cast].to_csv(sample_data_dir+cast.replace('cnv','csv'))

# %%
cruise_data[cast].columns
# Out:
# Index(['c0mS/cm', 'c1mS/cm', 'wetStar', 'sbeox0V', 't090C', 't190C', 'timeS',
#        'CStarAt0', 'CStarTr0', 'sbeox1V', 'par', 'v7', 'v6', 'v5', 'v4', 'v3',
#        'v2', 'sal00', 'sal11', 'sigma-t00', 'sigma-t11', 'sbeox0ML/L',
#        'sbox0Mm/Kg', 'sbeox0PS', 'sbeox1ML/L', 'sbox1Mm/Kg', 'sbeox1PS',
#        'flag'],
#       dtype='object')

# %% [markdown]
# ## Range Check

# %%
range_summary = pd.DataFrame()

for cast in cruise_data.keys():
    if (not cast.startswith('u')) and (not cast.startswith('d')):
        cast_range = cruise_data[cast].describe().loc[['min','max']][['wetStar','t090C', 't190C','CStarAt0', 'CStarTr0', 
                                                                      'sal00', 'sal11','sbeox0PS','sbeox1PS','v7', 'par', 'v4',]]
        cast_range['cast'] = cast
        range_summary = pd.concat([range_summary,cast_range],ignore_index=True)

# %%
pd.set_option('display.max_rows', None)

def make_pretty(styler):
    styler.background_gradient(axis=0, cmap="YlGnBu_r")
    return styler

range_summary.style.pipe(make_pretty)
# Out:
# <style type="text/css">
# #T_ed2cf_row0_col0, #T_ed2cf_row47_col0, #T_ed2cf_row51_col0 {
#   background-color: #152772;
#   color: #f1f1f1;
# }
# #T_ed2cf_row0_col1, #T_ed2cf_row0_col2, #T_ed2cf_row1_col1, #T_ed2cf_row1_col2, #T_ed2cf_row44_col6, #T_ed2cf_row45_col6, #T_ed2cf_row58_col6, #T_ed2cf_row61_col6, #T_ed2cf_row74_col6 {
#   background-color: #edf8b2;
#   color: #000000;
# }
# #T_ed2cf_row0_col3, #T_ed2cf_row1_col3, #T_ed2cf_row7_col5, #T_ed2cf_row9_col5, #T_ed2cf_row19_col1, #T_ed2cf_row19_col2, #T_ed2cf_row25_col6, #T_ed2cf_row31_col0, #T_ed2cf_row37_col7, #T_ed2cf_row37_col8, #T_ed2cf_row41_col1, #T_ed2cf_row41_col2, #T_ed2cf_row89_col4, #T_ed2cf_row89_col9, #T_ed2cf_row95_col10, #T_ed2cf_row95_col11 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_ed2cf_row0_col4, #T_ed2cf_row1_col9, #T_ed2cf_row84_col0, #T_ed2cf_row86_col0, #T_ed2cf_row88_col0, #T_ed2cf_row92_col3 {
#   background-color: #0d2163;
#   color: #f1f1f1;
# }
# #T_ed2cf_row0_col5, #T_ed2cf_row1_col5, #T_ed2cf_row4_col6, #T_ed2cf_row14_col1, #T_ed2cf_row14_col2, #T_ed2cf_row30_col6, #T_ed2cf_row33_col6, #T_ed2cf_row40_col1, #T_ed2cf_row40_col2, #T_ed2cf_row55_col5 {
#   background-color: #f8fcc9;
#   color: #000000;
# }
# #T_ed2cf_row0_col6, #T_ed2cf_row1_col6, #T_ed2cf_row7_col1, #T_ed2cf_row7_col2, #T_ed2cf_row65_col1, #T_ed2cf_row65_col2, #T_ed2cf_row83_col6 {
#   background-color: #f4fbc0;
#   color: #000000;
# }
# #T_ed2cf_row0_col7, #T_ed2cf_row1_col7, #T_ed2cf_row6_col8, #T_ed2cf_row8_col8, #T_ed2cf_row12_col7, #T_ed2cf_row14_col7, #T_ed2cf_row16_col7, #T_ed2cf_row17_col10, #T_ed2cf_row21_col7, #T_ed2cf_row23_col7, #T_ed2cf_row39_col7, #T_ed2cf_row47_col7, #T_ed2cf_row57_col7, #T_ed2cf_row59_col7, #T_ed2cf_row59_col11, #T_ed2cf_row67_col7, #T_ed2cf_row83_col7, #T_ed2cf_row85_col7, #T_ed2cf_row87_col7 {
#   background-color: #24449c;
#   color: #f1f1f1;
# }
# #T_ed2cf_row0_col8, #T_ed2cf_row1_col8, #T_ed2cf_row14_col8, #T_ed2cf_row19_col0, #T_ed2cf_row23_col8, #T_ed2cf_row47_col8, #T_ed2cf_row57_col8, #T_ed2cf_row59_col8, #T_ed2cf_row85_col8 {
#   background-color: #1f7bb6;
#   color: #f1f1f1;
# }
# #T_ed2cf_row0_col9, #T_ed2cf_row18_col11, #T_ed2cf_row22_col0, #T_ed2cf_row50_col11 {
#   background-color: #0d2161;
#   color: #f1f1f1;
# }
# #T_ed2cf_row0_col10, #T_ed2cf_row0_col11, #T_ed2cf_row1_col10, #T_ed2cf_row1_col11, #T_ed2cf_row2_col10, #T_ed2cf_row4_col10, #T_ed2cf_row6_col10, #T_ed2cf_row6_col11, #T_ed2cf_row7_col10, #T_ed2cf_row8_col10, #T_ed2cf_row8_col11, #T_ed2cf_row10_col10, #T_ed2cf_row12_col10, #T_ed2cf_row12_col11, #T_ed2cf_row13_col10, #T_ed2cf_row14_col10, #T_ed2cf_row16_col10, #T_ed2cf_row18_col10, #T_ed2cf_row20_col10, #T_ed2cf_row22_col10, #T_ed2cf_row24_col10, #T_ed2cf_row24_col11, #T_ed2cf_row25_col10, #T_ed2cf_row26_col7, #T_ed2cf_row26_col8, #T_ed2cf_row26_col10, #T_ed2cf_row26_col11, #T_ed2cf_row27_col10, #T_ed2cf_row30_col0, #T_ed2cf_row30_col10, #T_ed2cf_row30_col11, #T_ed2cf_row32_col0, #T_ed2cf_row32_col10, #T_ed2cf_row34_col0, #T_ed2cf_row34_col10, #T_ed2cf_row34_col11, #T_ed2cf_row35_col10, #T_ed2cf_row36_col10, #T_ed2cf_row38_col10, #T_ed2cf_row40_col10, #T_ed2cf_row40_col11, #T_ed2cf_row41_col10, #T_ed2cf_row42_col10, #T_ed2cf_row46_col10, #T_ed2cf_row46_col11, #T_ed2cf_row47_col10, #T_ed2cf_row48_col0, #T_ed2cf_row48_col10, #T_ed2cf_row50_col0, #T_ed2cf_row50_col10, #T_ed2cf_row52_col1, #T_ed2cf_row52_col2, #T_ed2cf_row52_col10, #T_ed2cf_row52_col11, #T_ed2cf_row53_col10, #T_ed2cf_row54_col10, #T_ed2cf_row56_col10, #T_ed2cf_row58_col10, #T_ed2cf_row58_col11, #T_ed2cf_row59_col10, #T_ed2cf_row60_col10, #T_ed2cf_row60_col11, #T_ed2cf_row62_col10, #T_ed2cf_row64_col10, #T_ed2cf_row64_col11, #T_ed2cf_row65_col10, #T_ed2cf_row66_col10, #T_ed2cf_row70_col10, #T_ed2cf_row70_col11, #T_ed2cf_row71_col10, #T_ed2cf_row72_col10, #T_ed2cf_row74_col0, #T_ed2cf_row74_col10, #T_ed2cf_row76_col10, #T_ed2cf_row76_col11, #T_ed2cf_row77_col10, #T_ed2cf_row78_col10, #T_ed2cf_row80_col10, #T_ed2cf_row80_col11, #T_ed2cf_row81_col10, #T_ed2cf_row82_col0, #T_ed2cf_row82_col10, #T_ed2cf_row84_col10, #T_ed2cf_row86_col10, #T_ed2cf_row86_col11, #T_ed2cf_row87_col10, #T_ed2cf_row88_col3, #T_ed2cf_row88_col4, #T_ed2cf_row88_col9, #T_ed2cf_row88_col10, #T_ed2cf_row90_col10, #T_ed2cf_row90_col11, #T_ed2cf_row92_col5, #T_ed2cf_row92_col6, #T_ed2cf_row92_col10, #T_ed2cf_row92_col11, #T_ed2cf_row94_col3, #T_ed2cf_row94_col10, #T_ed2cf_row94_col11 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_ed2cf_row1_col0, #T_ed2cf_row10_col7, #T_ed2cf_row71_col0, #T_ed2cf_row85_col0, #T_ed2cf_row92_col4 {
#   background-color: #1d2e83;
#   color: #f1f1f1;
# }
# #T_ed2cf_row1_col4, #T_ed2cf_row36_col0, #T_ed2cf_row38_col0, #T_ed2cf_row71_col11, #T_ed2cf_row81_col0 {
#   background-color: #0e2265;
#   color: #f1f1f1;
# }
# #T_ed2cf_row2_col0, #T_ed2cf_row44_col0, #T_ed2cf_row53_col11, #T_ed2cf_row73_col0, #T_ed2cf_row83_col0, #T_ed2cf_row94_col7, #T_ed2cf_row94_col8 {
#   background-color: #102369;
#   color: #f1f1f1;
# }
# #T_ed2cf_row2_col1, #T_ed2cf_row2_col2, #T_ed2cf_row21_col6, #T_ed2cf_row42_col1, #T_ed2cf_row42_col2, #T_ed2cf_row66_col6, #T_ed2cf_row67_col6, #T_ed2cf_row68_col6 {
#   background-color: #e9f7b1;
#   color: #000000;
# }
# #T_ed2cf_row2_col3, #T_ed2cf_row3_col3, #T_ed2cf_row4_col3, #T_ed2cf_row5_col3, #T_ed2cf_row6_col3, #T_ed2cf_row7_col3, #T_ed2cf_row8_col3, #T_ed2cf_row9_col3, #T_ed2cf_row10_col3, #T_ed2cf_row11_col3, #T_ed2cf_row12_col3, #T_ed2cf_row13_col3, #T_ed2cf_row14_col3, #T_ed2cf_row15_col3, #T_ed2cf_row16_col3, #T_ed2cf_row17_col3, #T_ed2cf_row18_col3, #T_ed2cf_row19_col3, #T_ed2cf_row20_col3, #T_ed2cf_row21_col3, #T_ed2cf_row22_col3, #T_ed2cf_row23_col3, #T_ed2cf_row24_col3, #T_ed2cf_row25_col3, #T_ed2cf_row26_col3, #T_ed2cf_row27_col3, #T_ed2cf_row30_col3, #T_ed2cf_row31_col3, #T_ed2cf_row32_col3, #T_ed2cf_row33_col3, #T_ed2cf_row34_col3, #T_ed2cf_row35_col3, #T_ed2cf_row36_col3, #T_ed2cf_row37_col3, #T_ed2cf_row38_col3, #T_ed2cf_row39_col3, #T_ed2cf_row40_col3, #T_ed2cf_row41_col3, #T_ed2cf_row42_col3, #T_ed2cf_row43_col3, #T_ed2cf_row44_col3, #T_ed2cf_row45_col3, #T_ed2cf_row46_col3, #T_ed2cf_row48_col3, #T_ed2cf_row49_col3, #T_ed2cf_row50_col3, #T_ed2cf_row51_col3, #T_ed2cf_row52_col3, #T_ed2cf_row53_col3, #T_ed2cf_row54_col3, #T_ed2cf_row55_col3, #T_ed2cf_row56_col3, #T_ed2cf_row57_col3, #T_ed2cf_row58_col3, #T_ed2cf_row59_col0, #T_ed2cf_row59_col3, #T_ed2cf_row60_col0, #T_ed2cf_row60_col3, #T_ed2cf_row61_col3, #T_ed2cf_row62_col3, #T_ed2cf_row63_col3, #T_ed2cf_row64_col3, #T_ed2cf_row65_col3, #T_ed2cf_row66_col0, #T_ed2cf_row66_col3, #T_ed2cf_row67_col3, #T_ed2cf_row68_col3, #T_ed2cf_row69_col3, #T_ed2cf_row70_col3, #T_ed2cf_row71_col3, #T_ed2cf_row72_col3, #T_ed2cf_row73_col3, #T_ed2cf_row74_col3, #T_ed2cf_row75_col3, #T_ed2cf_row76_col3, #T_ed2cf_row77_col3, #T_ed2cf_row78_col3, #T_ed2cf_row79_col3, #T_ed2cf_row80_col3, #T_ed2cf_row81_col3, #T_ed2cf_row82_col3, #T_ed2cf_row83_col3, #T_ed2cf_row84_col3, #T_ed2cf_row85_col3, #T_ed2cf_row86_col3, #T_ed2cf_row87_col3, #T_ed2cf_row90_col3 {
#   background-color: #11246b;
#   color: #f1f1f1;
# }
# #T_ed2cf_row2_col4, #T_ed2cf_row2_col9, #T_ed2cf_row3_col4, #T_ed2cf_row3_col9, #T_ed2cf_row4_col4, #T_ed2cf_row4_col9, #T_ed2cf_row5_col4, #T_ed2cf_row5_col9, #T_ed2cf_row6_col4, #T_ed2cf_row6_col9, #T_ed2cf_row7_col4, #T_ed2cf_row7_col9, #T_ed2cf_row9_col4, #T_ed2cf_row9_col9, #T_ed2cf_row10_col4, #T_ed2cf_row10_col9, #T_ed2cf_row11_col4, #T_ed2cf_row11_col9, #T_ed2cf_row12_col4, #T_ed2cf_row12_col9, #T_ed2cf_row13_col4, #T_ed2cf_row13_col9, #T_ed2cf_row14_col4, #T_ed2cf_row14_col9, #T_ed2cf_row15_col4, #T_ed2cf_row15_col9, #T_ed2cf_row16_col4, #T_ed2cf_row16_col9, #T_ed2cf_row17_col4, #T_ed2cf_row17_col9, #T_ed2cf_row18_col4, #T_ed2cf_row18_col9, #T_ed2cf_row19_col4, #T_ed2cf_row19_col9, #T_ed2cf_row20_col4, #T_ed2cf_row20_col9, #T_ed2cf_row21_col4, #T_ed2cf_row21_col9, #T_ed2cf_row22_col4, #T_ed2cf_row22_col9, #T_ed2cf_row23_col4, #T_ed2cf_row23_col9, #T_ed2cf_row24_col4, #T_ed2cf_row24_col9, #T_ed2cf_row25_col4, #T_ed2cf_row25_col9, #T_ed2cf_row26_col4, #T_ed2cf_row26_col9, #T_ed2cf_row27_co

# %% [markdown]
# ## Post Cruise Processing with additional meta information

# %%
###############################################################
# edit to point to {cruise sepcific} raw datafiles 
datafile = sample_data_dir+'rawconverted/' #<- point to cruise and process all files within
cruise_name = 'NW2101' #no hyphens
cruise_meta_file = sample_data_dir+'logs/NW2101.yaml'
inst_meta_file = sample_data_dir+'logs/EMA_standard_CTD.yaml'
group_meta_file = ecofocipy_dir+'staticdata/institutional_meta_example_ctd.yaml'
inst_shortname = '' #keep as placeholder for now
###############################################################

#init and load data
cruise = sbe_ctd_parser.sbe9_11p()
filename_list = sorted(glob.glob(datafile + '*.cnv'))

(cruise_data,cruise_header) = cruise.parse(filename_list)

# %% [markdown]
# ## Time Properties
#
# Not traditionally dealt with for CTD files as they are likely dynamically updated via GPS feed.  However, FOCI tends to label the date/time with the ***at depth*** time-stamp
#
# ## Depth Properties and other assumptions
#
# - currently, all processing and binning (1m for FOCI) is done via seabird routines and the windows software.  This may change with the python ctd package for a few tasks

# %% [markdown]
# ## Load all external meta information

# %%
#cruise info
with open(cruise_meta_file) as file:
    cruise_config = yaml.full_load(file)

#instrument info
with open(inst_meta_file) as file:
    inst_config = yaml.full_load(file)

#institutional info
with open(group_meta_file) as file:
    group_config = yaml.full_load(file)

# %%
inst_config
# Out:
# {'time': {'epic_key': 'TIM_601',
#   'name': 'time',
#   'generic_name': 'time',
#   'standard_name': 'time',
#   'long_name': 'date and time since reference time'},
#  'depth': {'epic_key': 'D_3',
#   'generic_name': 'depth',
#   'units': 'meter',
#   'long_name': 'depth below surface (meters)',
#   'standard_name': 'depth',
#   'positive': 'down'},
#  'latitude': {'epic_key': 'LON_501',
#   'name': 'latitude',
#   'generic_name': 'latitude',
#   'units': 'degrees_north',
#   'long_name': 'latitude',
#   'standard_name': 'latitude'},
#  'longitude': {'epic_key': 'LAT_500',
#   'name': 'longitude',
#   'generic_name': 'longitude',
#   'units': 'degrees_east',
#   'long_name': 'longitude',
#   'standard_name': 'longitude'},
#  'temperature_ch1': {'epic_key': 'T_28',
#   'generic_name': 'temp channel 1',
#   'long_name': 'Sea temperature in-situ ITS-90 scale',
#   'standard_name': 'sea_water_temperature',
#   'units': 'degree_C'},
#  'temperature_ch2': {'epic_key': 'T2_35',
#   'generic_name': 'temp channel 2',
#   'long_name': 'Sea temperature in-situ ITS-90 scale',
#   'standard_name': 'sea_water_temperature',
#   'units': 'degree_C'},
#  'pressure': {'epic_key': 'P_1',
#   'generic_name': 'pres',
#   'units': 'decibar',
#   'long_name': 'Sea water pressure, equals 0 at sea-level',
#   'standard_name': 'sea_water_pressure_due_to_sea_water'},
#  'salinity_ch1': {'epic_key': 'S_41',
#   'generic_name': 'psal channel 1',
#   'units': 'PSU',
#   'long_name': 'Practical salinity in-situ PSS-78 scale',
#   'standard_name': 'sea_water_practical_salinity'},
#  'salinity_ch2': {'epic_key': 'S_42',
#   'generic_name': 'psal channel 2',
#   'units': 'PSU',
#   'long_name': 'Practical salinity in-situ PSS-78 scale',
#   'standard_name': 'sea_water_practical_salinity'},
#  'chlor_fluorescence': {'epic_key': 'F_903',
#   'generic_name': 'chlor_fluorescence',
#   'long_name': 'Mass Concdentration of chlorophyll from chlorophyll fluorescence',
#   'standard_name': 'mass_concentration_of_chlorophyll_in_sea_water',
#   'units': 'ugrams/l',
#   'instrument': 'wetlabs wetstar'},
#  'par': {'generic_name': 'par',
#   'epic_key': 'PAR_905',
#   'long_name': 'Photosynthetic Active Radiation',
#   'standard_name': 'omnidirectional_photosynthetic_photon_spherical_irradiance_in_sea_water',
#   'units': 'uEin cm-2 s-1'},
#  'oxy_conc_ch1': {'generic_name': 'oxy_conc channel 1',
#   'epic_key': 'O_65',
#   'long_name': 'concentration of oxygen in seawater',
#   'standard_name': 'mole_concentration_of_dissolved_molecular_oxygen_in_sea_water',
#   'units': 'micromole/kg'},
#  'oxy_conc_ch2': {'generic_name': 'oxy_conc channel 2',
#   'epic_key': 'CTDOXY_4221',
#   'long_name': 'concentration of oxygen in seawater',
#   'standard_name': 'mole_concentration_of_dissolved_molecular_oxygen_in_sea_water',
#   'units': 'micromole/kg'},
#  'oxy_concM_ch1': {'generic_name': 'oxy_concM channel 1',
#   'epic_key': 'O_65',
#   'long_name': 'concentration of oxygen in seawater',
#   'standard_name': 'mole_concentration_of_dissolved_molecular_oxygen_in_sea_water',
#   'units': 'ml/l'},
#  'oxy_concM_ch2': {'generic_name': 'oxy_concM channel 2',
#   'epic_key': 'O_2060',
#   'long_name': 'concentration of oxygen in seawater',
#   'standard_name': 'mole_concentration_of_dissolved_molecular_oxygen_in_sea_water',
#   'units': 'ml/l'},
#  'oxy_percentsat_ch1': {'generic_name': 'oxy_psat channel 1',
#   'epic_key': 'OST_62',
#   'units': 'percent',
#   'long_name': 'Percent Saturation of oxygen over air',
#   'standard_name': 'fractional_saturation_of_oxygen_in_sea_water'},
#  'oxy_percentsat_ch2': {'generic_name': 'oxy_psat channel 2',
#   'epic_key': 'CTDOST_4220',
#   'units': 'percent',
#   'long_name': 'Percent Saturation of oxygen over air',
#   'standard_name': 'fractional_saturation_of_oxygen_in_sea_water'},
#  'transmittance': {'generic_name': 'cstar transmittance',
#   'units': 'percent',
#   'long_name': 'horizontal transmittance in sea water',
#   'standard_name': 'optical_transmission_ratio_in_sea_water',
#   'instrument': 'CStar'},
#  'attenuation': {'generic_name': 'cstar beam attenuation',
#   'units': 'm-1',
#   'long_name': 'horizontal beam attenuation in sea water',
#   'standard_name': 'volume_beam_attenuation_coefficient_in_sea_water',
#   'instrument': 'CStar'}}

# %%
cruise_config['CTDCasts']['CTD001']
# Out:
# {'id': 53918,
#  'Vessel': 'NorthWest Explorer',
#  'CruiseID': 'NW2101',
#  'Project_Leg': '',
#  'UniqueCruiseID': 'NW2101',
#  'Project': 'Northern Bering Sea (NBS)',
#  'StationNo_altname': '1',
#  'ConsecutiveCastNo': 'CTD001',
#  'LatitudeDeg': 60,
#  'LatitudeMin': 0.0,
#  'LongitudeDeg': 168,
#  'LongitudeMin': 0.0,
#  'GMTDay': 30,
#  'GMTMonth': 'Aug',
#  'GMTYear': 2021,
#  'GMTTime': 58620,
#  'DryBulb': -99.9,
#  'RelativeHumidity': -999,
#  'WetBulb': -99.9,
#  'Pressure': -9999,
#  'SeaState': '',
#  'Visibility': '',
#  'WindDir': -999,
#  'WindSpd': -99.9,
#  'CloudAmt': '',
#  'CloudType': '',
#  'Weather': '',
#  'SurfaceTemp': -99.9,
#  'BottomDepth': 21,
#  'StationNameID': '',
#  'MaxDepth': -9999,
#  'InstrumentSerialNos': '',
#  'Notes': 'First Station, forgot to take sensor caps off',
#  'NutrientBtlNiskinNo': '1;2;3',
#  'NutrientBtlNumbers': ';2;3',
#  'OxygenBtlNiskinNo': '',
#  'OxygenBtlNumbers': '',
#  'SalinityBtlNiskinNo': '3',
#  'SalinityBtlNumbers': '1',
#  'ChlorophyllBtlNiskinNo': '1;2;3',
#  'ChlorophyllBtlVolumes': ';250;250',
#  'InstrumentType': 'SBE911plus',
#  'WaterMassCode': 'B',
#  'isMooringProfileCast': 'n',
#  'MooringID': '',
#  'QualityControlled': 'n',
#  'FileName': ''}

# %%
for cast in cruise_data.keys():
    print(f'Processing Cast {cast}')
    try:
        #output cruise cast stats here
        #cruise_data[cast].describe()
        #cruise_data['ctd001.cnv'].hist() - seaborn may have a better summary plot than just a bunch of histograms
        #sns.pairplot(cruise_data[cast])
        lower_columns = [x.lower() for x in cruise_data[cast].columns]
        cruise_data[cast].columns = lower_columns
        cruise_data[cast] = cruise_data[cast].rename(columns={
                            't090c':'temperature_ch1',
                            't190c':'temperature_ch2',
                            'sal00':'salinity_ch1',
                            'sal11':'salinity_ch2',
                            'sbox0mm/kg':'oxy_conc_ch1',
                            'sbeox0ml/l':'oxy_concM_ch1',
                            'sbox1mm/kg':'oxy_conc_ch2',
                            'sbeox1ml/l':'oxy_concM_ch2',
                            'sbeox0ps':'oxy_percentsat_ch1',
                            'sbeox1ps':'oxy_percentsat_ch2',
                            'sigma-t00':'sigma_t_ch1',
                            'sigma-t11':'sigma_t_ch2',
                            'wetstar':'chlor_fluorescence',
                            # 'turbwetntu0':'turbidity',
                            'cstarat0':'attenuation',
                            'cstartr0':'transmittance',
                            'prdm':'pressure',
                            'empty':'empty', #this will be ignored
                            'flag':'flag'})

        cruise_data[cast].index.rename('depth',inplace=True)
        #cruise_data[cast].sample()

        cruise_data_nc = ncCFsave.EcoFOCI_CFnc(df=cruise_data[cast], 
                                instrument_yaml=inst_config, 
                                operation_yaml=cruise_config,
                                operation_type='ctd')
        cruise_data_nc.expand_dimensions(dim_names=['latitude','longitude','time'],geophys_sort=False)
        cruise_data_nc.variable_meta_data(variable_keys=list(cruise_data[cast].columns.values),drop_missing=True)
        cruise_data_nc.dimension_meta_data(variable_keys=['depth','latitude','longitude'])
        cruise_data_nc.temporal_geospatioal_meta_data_ctd(positiveE=False,conscastno=cast.split('.')[0])

        cruise_data_nc.var_qcflag_init(dim_names=['depth','latitude','longitude','time'])

        #interp to sfc for list of vars
        cruise_data_nc.interp2sfc(novars=['par'])

        #add global attributes
        cruise_data_nc.deployment_meta_add(conscastno=cast.upper().split('.')[0])
        cruise_data_nc.get_xdf()

        #add instituitonal global attributes
        cruise_data_nc.institution_meta_add(group_config)

        #add creation date/time - provenance data
        cruise_data_nc.provinance_meta_add()

        #provide intial qc status field
        cruise_data_nc.qc_status(qc_status='unknown')

        cast_label = cast.split('.')[0].split('d')[-1]
        cruise_data_nc.xarray2netcdf_save(xdf = cruise_data_nc.get_xdf(),
                                filename=sample_data_dir+cruise_name+'c'+cast_label.zfill(3)+'_ctd.nc',format="NETCDF3_CLASSIC")
        #generate editable csv files
        to_edit = True
        if to_edit:
            if not cast[0] in ['d','u']: #dont save editable up and downcast files, just nc files for plotting... all u/d files can be removed after final data
                cruise_data_nc.get_xdf().to_dataframe().to_csv(sample_data_dir+cruise_name+'c'+cast_label.zfill(3)+'_ctd.to_edit.csv')  

    except:
       print('Conversion Failed')
# Out:
# Processing Cast ctd001.cnv
# Processing Cast ctd002.cnv
# Processing Cast ctd003.cnv
# Processing Cast ctd004.cnv
# Processing Cast ctd005.cnv
# Processing Cast ctd006.cnv
# Processing Cast ctd007.cnv
# Processing Cast ctd008.cnv
# Processing Cast ctd009.cnv
# Processing Cast ctd010.cnv
# Processing Cast ctd011.cnv
# Processing Cast ctd012.cnv
# Processing Cast ctd013.cnv
# Processing Cast ctd013_2nd_cast.cnv
# Conversion Failed
# Processing Cast ctd013_upcast.cnv
# Conversion Failed
# Processing Cast ctd014.cnv
# Processing Cast ctd015.cnv
# Processing Cast ctd016.cnv
# Processing Cast ctd017.cnv
# Processing Cast ctd018.cnv
# Processing Cast ctd019.cnv
# Processing Cast ctd020.cnv
# Processing Cast ctd021.cnv
# Processing Cast ctd022.cnv
# Processing Cast ctd023.cnv
# Processing Cast ctd024.cnv
# Processing Cast ctd025.cnv
# Processing Cast ctd026.cnv
# Processing Cast ctd027.cnv
# Processing Cast ctd028.cnv
# Processing Cast ctd029.cnv
# Processing Cast ctd030.cnv
# Processing Cast ctd031.cnv
# Processing Cast ctd032.cnv
# Processing Cast ctd033.cnv
# Processing Cast ctd034.cnv
# Processing Cast ctd035.cnv
# Processing Cast ctd036.cnv
# Processing Cast ctd037.cnv
# Processing Cast ctd038.cnv
# Processing Cast ctd039.cnv
# Processing Cast ctd040.cnv
# Processing Cast ctd041.cnv
# Processing Cast ctd042.cnv
# Processing Cast ctd043.cnv
# Processing Cast ctd044.cnv
# Processing Cast ctd045.cnv
# Processing Cast ctd046.cnv
# Processing Cast dctd001.cnv
# Conversion Failed
# Processing Cast dctd002.cnv
# Conversion Failed
# Processing Cast dctd003.cnv
# Conversion Failed
# Processing Cast dctd004.cnv
# Conversion Failed
# Processing Cast dctd005.cnv
# Conversion Failed
# Processing Cast dctd006.cnv
# Conversion Failed
# Processing Cast dctd007.cnv
# Conversion Failed
# Processing Cast dctd008.cnv
# Conversion Failed
# Processing Cast dctd009.cnv
# Conversion Failed
# Processing Cast dctd010.cnv
# Conversion Failed
# Processing Cast dctd011.cnv
# Conversion Failed
# Processing Cast dctd012.cnv
# Conversion Failed
# Processing Cast dctd013.cnv
# Conversion Failed
# Processing Cast dctd013_2nd_cast.cnv
# Conversion Failed
# Processing Cast dctd013_upcast.cnv
# Conversion Failed
# Processing Cast dctd014.cnv
# Conversion Failed
# Processing Cast dctd015.cnv
# Conversion Failed
# Processing Cast dctd016.cnv
# Conversion Failed
# Processing Cast dctd017.cnv
# Conversion Failed
# Processing Cast dctd018.cnv
# Conversion Failed
# Processing Cast dctd019.cnv
# Conversion Failed
# Processing Cast dctd020.cnv
# Conversion Failed
# Processing Cast dctd021.cnv
# Conversion Failed
# Processing Cast dctd022.cnv
# Conversion Failed
# Processing Cast dctd023.cnv
# Conversion Failed
# Processing Cast dctd024.cnv
# Conversion Failed
# Processing Cast dctd025.cnv
# Conversion Failed
# Processing Cast dctd026.cnv
# Conversion Failed
# Processing Cast dctd027.cnv
# Conversion Failed
# Processing Cast dctd028.cnv
# Conversion Failed
# Processing Cast dctd029.cnv
# Conversion Failed
# Processing Cast dctd030.cnv
# Conversion Failed
# Processing Cast dctd031.cnv
# Conversion Failed
# Processing Cast dctd032.cnv
# Conversion Failed
# Processing Cast dctd033.cnv
# Conversion Failed
# Processing Cast dctd034.cnv
# Conversion Failed
# Processing Cast dctd035.cnv
# Conversion Failed
# Processing Cast dctd036.cnv
# Conversion Failed
# Processing Cast dctd037.cnv
# Conversion Failed
# Processing Cast dctd038.cnv
# Conversion Failed
# Processing Cast dctd039.cnv
# Conversion Failed
# Processing Cast dctd040.cnv
# Conversion Failed
# Processing Cast dctd041.cnv
# Conversion Failed
# Processing Cast dctd042.cnv
# Conversion Failed
# Processing Cast dctd043.cnv
# Conversion Failed
# Processing Cast dctd044.cnv
# Conversion Failed
# Processing Cast dctd045.cnv
# Conversion Failed
# Processing Cast dctd046.cnv
# Conversion Failed
# Processing Cast uctd001.cnv
# Conversion Failed
# Processing Cast uctd002.cnv
# Conversion Failed
# Processing Cast uctd003.cnv
# Conversion Failed
# Processing Cast uctd004.cnv
# Conversion Failed
# Processing Cast uctd005.cnv
# Conversion Failed
# Processing Cast uctd006.cnv
# Conversion Failed
# Processing Cast uctd007.cnv
# Conversion Failed
# Processing Cast uctd008.cnv
# Conversion Failed
# Processing Cast uctd009.cnv
# Conversion Failed
# Processing Cast uctd010.cnv
# Conversion Failed
# Processing Cast uctd011.cnv
# Conversion Failed
# Processing Cast uctd012.cnv
# Conversion Failed
# Processing Cast uctd013.cnv
# Conversion Failed
# Processing Cast uctd013_2nd_cast.cnv
# Conversion Failed
# Processing Cast uctd013_upcast.cnv
# Conversion Failed
# Processing Cast uctd014.cnv
# Conversion Failed
# Processing Cast uctd015.cnv
# Conversion Failed
# Processing Cast uctd016.cnv
# Conversion Failed
# Processing Cast uctd017.cnv
# Conversion Failed
# Processing Cast uctd018.cnv
# Conversion Failed
# Processing Cast uctd019.cnv
# Conversion Failed
# Processing Cast uctd020.cnv
# Conversion Failed
# Processing Cast uctd021.cnv
# Conversion Failed
# Processing Cast uctd022.cnv
# Conversion Failed
# Processing Cast uctd023.cnv
# Conversion Failed
# Processing Cast uctd024.cnv
# Conversion Failed
# Processing Cast uctd025.cnv
# Conversion Failed
# Processing Cast uctd026.cnv
# Conversion Failed
# Processing Cast uctd027.cnv
# Conversion Failed
# Processing Cast uctd028.cnv
# Conversion Failed
# Processing Cast uctd029.cnv
# Conversion Failed
# Processing Cast uctd030.cnv
# Conversion Failed
# Processing Cast uctd031.cnv
# Conversion Failed
# Processing Cast uctd032.cnv
# Conversion Failed
# Processing Cast uctd033.cnv
# Conversion Failed
# Processing Cast uctd034.cnv
# Conversion Failed
# Processing Cast uctd035.cnv
# Conversion Failed
# Processing Cast uctd036.cnv
# Conversion Failed
# Processing Cast uctd037.cnv
# Conversion Failed
# Processing Cast uctd038.cnv
# Conversion Failed
# Processing Cast uctd039.cnv
# Conversion Failed
# Processing Cast uctd040.cnv
# Conversion Failed
# Processing Cast uctd041.cnv
# Conversion Failed
# Processing Cast uctd042.cnv
# Conversion Failed
# Processing Cast uctd043.cnv
# Conversion Failed
# Processing Cast uctd044.cnv
# Conversion Failed
# Processing Cast uctd045.cnv
# Conversion Failed
# Processing Cast uctd046.cnv
# Conversion Failed

# %% [markdown]
# ## QC Next Steps

# %%
import ecofocipy.plots.sbe_ctd_plots as sbe_ctd_plots
import os
import xarray as xa
import seaborn as sns
import numpy as np

# %%
sample_data_dir = '/Users/bell/ecoraid/2021/CTDcasts/nw2101/working/' #root path to cruise directory working repo

# %% [markdown]
# ### QC of data (plot parameters with other instruments)
# - be sure to updated the qc_status for the file and the history for future steps
# - from NRT csv files... make edits then use that to modify netcdf?
# - **Better Yet** export netcdf files with variable flags to csv and edit then reingest and modify
#     - modify netcdf in place and provide a qcflag?
#
#
# ### Likely first edits
# - research issues noted in cruise logs
# - remove failed instrument (clogs, or other challenges that arent correctable)
# - extrapolate to sfc (not par though)
# - despike depths (interpolate between depths)
# - check for common issues
#     - lags in salinity when going through interface

# %%
#test for salinity bottle run needs
for cast in sorted(os.listdir(sample_data_dir)):
    if cast.endswith('.nc'):
        cruise_data_nc = xa.load_dataset(sample_data_dir+cast)
        saldiff = cruise_data_nc.salinity_ch1 - cruise_data_nc.salinity_ch2
        print(f"Profile Averaged Salinity {cast} Difference,STD (chan1-chan2){saldiff.mean().values},{saldiff.std().values}")        
        saldiff.plot.hist(bins=50,xlim=[-.005,.005])
# Out:
# Profile Averaged Salinity NW2101c001_ctd.nc Difference,STD (chan1-chan2)-0.003242857142856183,0.00033462335411012814
# Profile Averaged Salinity NW2101c002_ctd.nc Difference,STD (chan1-chan2)-0.0004999999999998661,0.0004819315973414462
# Profile Averaged Salinity NW2101c003_ctd.nc Difference,STD (chan1-chan2)-0.00041153846153852726,0.0027160246576247347
# Profile Averaged Salinity NW2101c004_ctd.nc Difference,STD (chan1-chan2)-0.001692753623188065,0.009879950695772778
# Profile Averaged Salinity NW2101c005_ctd.nc Difference,STD (chan1-chan2)-0.001658333333332133,0.00741856436396095
# Profile Averaged Salinity NW2101c006_ctd.nc Difference,STD (chan1-chan2)-0.0009312500000001981,0.0025016791236085576
# Profile Averaged Salinity NW2101c007_ctd.nc Difference,STD (chan1-chan2)-0.000563157894737306,0.00018555897435595538
# Profile Averaged Salinity NW2101c008_ctd.nc Difference,STD (chan1-chan2)-0.0006178571428564642,0.0002376275167872602
# Profile Averaged Salinity NW2101c009_ctd.nc Difference,STD (chan1-chan2)-0.000238461538461256,0.0001002954216187087
# Profile Averaged Salinity NW2101c010_ctd.nc Difference,STD (chan1-chan2)-0.0007590909090917238,0.0016715967029133944
# Profile Averaged Salinity NW2101c011_ctd.nc Difference,STD (chan1-chan2)-0.0007851851851854606,0.0005352076119869665
# Profile Averaged Salinity NW2101c012_ctd.nc Difference,STD (chan1-chan2)-0.001441666666666958,0.002313532051983677
# Profile Averaged Salinity NW2101c013_ctd.nc Difference,STD (chan1-chan2)0.2769847826086956,1.2846138494348152
# Profile Averaged Salinity NW2101c014_ctd.nc Difference,STD (chan1-chan2)-0.0020692307692316172,0.009404878816982515
# Profile Averaged Salinity NW2101c015_ctd.nc Difference,STD (chan1-chan2)-0.0021102040816325203,0.012245686369175791
# Profile Averaged Salinity NW2101c016_ctd.nc Difference,STD (chan1-chan2)-0.0016659090909090033,0.002471836194725518
# Profile Averaged Salinity NW2101c017_ctd.nc Difference,STD (chan1-chan2)-0.0006472222222215033,0.00117980368214108
# Profile Averaged Salinity NW2101c018_ctd.nc Difference,STD (chan1-chan2)-0.002185714285715155,0.005487629873875902
# Profile Averaged Salinity NW2101c019_ctd.nc Difference,STD (chan1-chan2)-0.0018380952380956913,0.00372769253157673
# Profile Averaged Salinity NW2101c020_ctd.nc Difference,STD (chan1-chan2)-0.013855172413792787,0.019986056970952324
# Profile Averaged Salinity NW2101c021_ctd.nc Difference,STD (chan1-chan2)-0.0003076923076917272,0.0017782712168592338
# Profile Averaged Salinity NW2101c022_ctd.nc Difference,STD (chan1-chan2)0.0006432432432430884,0.002092914757957493
# Profile Averaged Salinity NW2101c023_ctd.nc Difference,STD (chan1-chan2)-0.0014714285714285257,0.007690788730196037
# Profile Averaged Salinity NW2101c024_ctd.nc Difference,STD (chan1-chan2)-0.0016059999999995256,0.007580089973080625
# Profile Averaged Salinity NW2101c025_ctd.nc Difference,STD (chan1-chan2)-0.0012380952380949748,0.008841486418366904
# Profile Averaged Salinity NW2101c026_ctd.nc Difference,STD (chan1-chan2)0.0013676470588243127,0.004440370982661537
# Profile Averaged Salinity NW2101c027_ctd.nc Difference,STD (chan1-chan2)-0.0032933333333341843,0.012452012777949772
# Profile Averaged Salinity NW2101c028_ctd.nc Difference,STD (chan1-chan2)0.00016071428571391117,0.0047142897727257375
# Profile Averaged Salinity NW2101c029_ctd.nc Difference,STD (chan1-chan2)-0.0004031249999997266,0.0003820048878940682
# Profile Averaged Salinity NW2101c030_ctd.nc Difference,STD (chan1-chan2)-0.00039599999999964555,0.005263419420871113
# Profile Averaged Salinity NW2101c031_ctd.nc Difference,STD (chan1-chan2)-0.0005666666666666995,0.0003182292275551902
# Profile Averaged Salinity NW2101c032_ctd.nc Difference,STD (chan1-chan2)-0.00040454545454628806,0.0002820014067137958
# Profile Averaged Salinity NW2101c033_ctd.nc Difference,STD (chan1-chan2)0.0006185185185178665,0.0034160879766879553
# Profile Averaged Salinity NW2101c034_ctd.nc Difference,STD (chan1-chan2)-0.004009374999999649,0.011947184798494697
# Profile Averaged Salinity NW2101c035_ctd.nc Difference,STD (chan1-chan2)-0.00232187500000014,0.004270226455865198
# Profile Averaged Salinity NW2101c036_ctd.nc Difference,STD (chan1-chan2)-0.0019675000000002997,0.009659409596346641
# Profile Averaged Salinity NW2101c037_ctd.nc Difference,STD (chan1-chan2)-0.016645945945945848,0.03981929855759146
# Profile Averaged Salinity NW2101c038_ctd.nc Difference,STD (chan1-chan2)-0.010587999999999766,0.024903691613895298
# Profile Averaged Salinity NW2101c039_ctd.nc Difference,STD (chan1-chan2)-0.001785185185184972,0.00855516753970184
# Profile Averaged Salinity NW2101c040_ctd.nc Difference,STD (chan1-chan2)0.0022696969696966323,0.00921775246544582
# Profile Averaged Salinity NW2101c041_ctd.nc Difference,STD (chan1-chan2)0.00105000000000002,0.006075840133951578
# Profile Averaged Salinity NW2101c042_ctd.nc Difference,STD (chan1-chan2)0.0009838709677420492,0.002582833749372626
# Profile Averaged Salinity NW2101c043_ctd.nc Difference,STD (chan1-chan2)0.32344285714285703,1.512542673013583
# Profile Averaged Salinity NW2101c044_ctd.nc Difference,STD (chan1-chan2)-0.0253157894736843,0.08079821039679078
# Profile Averaged Salinity NW2101c045_ctd.nc Difference,STD (chan1-chan2)-0.04019999999999997,0.18992357075221775
# Profile Averaged Salinity NW2101c046_ctd.nc Difference,STD (chan1-chan2)-0.05448571428571435,0.32248748264480737

# %% [markdown]
# ## Generate Plots
#
#
# ### Make General Plots
# - 1:1 plots for paired instruments for each cast (tells if a sensor failed)
# - TS_Sigmat, Chlor/Par/Turb, Oxy,Temp
# - T/S property property plot
# - upcast/downcast plt

# %% [markdown]
# ### Look at max par values as hour of day - this cruise may have an issue with sensor

# %%
from matplotlib import pyplot as plt
import os

fig = plt.figure()

for cast in sorted(os.listdir(sample_data_dir)):
    if cast.endswith('.nc'):
        cruise_data_nc = xa.load_dataset(sample_data_dir+cast)
        plt.plot(cruise_data_nc.time.dt.hour,cruise_data_nc['par'].max(),'r.')

# %%
import seawater as sw

def sigmat_update(salinity=None,temperature=None):
    '''
    Changes to T or S (commonly to despike values or apply a salinity offset) will need corresponding changes in sigmat
    '''
    # calculate sigmaT at 0db gauge pressure (s, t, p=0)
    sigt = (sw.eos80.dens0(s=salinity, t=temperature) - 1000)
    
    return sigt

# %%
for cast in sorted(os.listdir(sample_data_dir)):
    if cast.endswith('.nc'):
        cruise_data_nc = xa.load_dataset(sample_data_dir+cast)
        ctd_df = cruise_data_nc.to_dataframe()
        

                #update sigmat (or calculate it I suppose)
        sigup = sigmat_update(salinity=ctd_df.salinity_ch1,
                              temperature=ctd_df.temperature_ch1)
        sigup2 = sigmat_update(salinity=ctd_df.salinity_ch2,
                              temperature=ctd_df.temperature_ch2)
        
        sbe_p = sbe_ctd_plots.CTDProfilePlot()
        plt,fig =sbe_p.plot3var(varname=['temperature_ch1','temperature_ch2','salinity_ch1','salinity_ch2','sigma_t_ch1','sigma_t_ch2'],
                          xdata=[ctd_df.temperature_ch1,ctd_df.temperature_ch2,ctd_df.salinity_ch1,ctd_df.salinity_ch2,sigup,sigup2],
                          ydata=ctd_df.index.get_level_values('depth'),
                          secondary=True,
                          xlabel=['Temperature','Salinity','Sigma-T'])

        DefaultSize = fig.get_size_inches()
        fig.set_size_inches( (DefaultSize[0], DefaultSize[1]*3) )
        plt.savefig(sample_data_dir+cast.replace('.nc','_TempSalSigmat.png'))
        plt.close(fig)

# %%
for cast in sorted(os.listdir(sample_data_dir)):
    if cast.endswith('.nc'):
        cruise_data_nc = xa.load_dataset(sample_data_dir+cast)
        ctd_df = cruise_data_nc.to_dataframe()
        
        sbe_p = sbe_ctd_plots.CTDProfilePlot()
        plt,fig =sbe_p.plot2var(varname=['temperature_ch1','temperature_ch2','oxy_percentsat_ch1','oxy_percentsat_ch2'],
                          xdata=[ctd_df.temperature_ch1,ctd_df.temperature_ch2,ctd_df.oxy_percentsat_ch1,ctd_df.oxy_percentsat_ch1],
                          ydata=ctd_df.index.get_level_values('depth'),
                          secondary=True,
                          xlabel=['Temperature','Oxygen Saturation'])

        DefaultSize = fig.get_size_inches()
        fig.set_size_inches( (DefaultSize[0], DefaultSize[1]*3) )
        plt.savefig(sample_data_dir+cast.replace('.nc','_TempOxy.png'))
        plt.close(fig)

# %%
for cast in sorted(os.listdir(sample_data_dir)):
    if cast.endswith('.nc'):
        cruise_data_nc = xa.load_dataset(sample_data_dir+cast)
        ctd_df = cruise_data_nc.to_dataframe()
        
        sbe_p = sbe_ctd_plots.CTDProfilePlot()
        plt,fig =sbe_p.plot3var(varname=['transmittance','','chlor_fluorescence','','par',''],
                          xdata=[ctd_df.transmittance,np.array([]),ctd_df.chlor_fluorescence,np.array([]),ctd_df.par,np.array([])],
                          ydata=ctd_df.index.get_level_values('depth'),
                          secondary=True,
                          xlabel=['Transmittance','Fluor','Par'])

        DefaultSize = fig.get_size_inches()
        fig.set_size_inches( (DefaultSize[0], DefaultSize[1]*3) )
        plt.savefig(sample_data_dir+cast.replace('.nc','_TransFluorPar.png'))
        plt.close(fig)

# %%
#cruise_data_nc.get_xdf().to_dataframe().columns
sns.pairplot(cruise_data_nc.to_dataframe()[['salinity_ch1', 'salinity_ch2',]])

# %%
# ## Export data from nc files
# for cast in sorted(os.listdir(sample_data_dir+'working/')):
#     if cast.endswith('.nc'):
#         cruise_data_nc = xa.load_dataset(sample_data_dir+'working/'+cast)
#         cruise_data_nc.to_dataframe().to_csv(sample_data_dir+'working/'+cast.replace('.nc','.to_edit.csv') )
