# %% [markdown]
# # Using EcoFOCIpy to process raw field data - DY2306
#
# *DY22306 - Ecofoci Spring Mooring Cruise*
#
# **Processed by Shaun Bell**
#
# A duplicate column of Fluorescence shows up
# ## CTD / Profile Data
#
# Basic workflow for each instrument grouping is *(initial archive level)*:
# - SBE workflow must happen first **done (performed on seperate windows system to convert to cnv)**
# - output initial files (pandas->csv) **ERDDAP NRT** when no meta data is added.  Good for quick analysis
#
# Other than hosting on an erddap server, the above can be done at sea
#
# For furthur processing, QC and archiving, the following tasks are to be done *(working or final data level)*:
# - Add metadata from cruise yaml files created from cast logs
# - apply any calibrations or corrections
#     + field corrections
#     + offsets
#     + spike analysis
#     + some QC were available... this would be old-school simple bounds mostly
# - save as CF netcdf via xarray or potentially csv file: so many of the steps above are optional
#     + **ERDDAP NRT** if no corrections, offsets or time bounds are applied but some meta data is (can be csv as this is useful at sea)
#     + **Working and awaiting QC** has no ERDDAP representation and is a holding spot
#     + **ERDDAP Final** fully calibrated, qc'd and populated with meta information
#
# Plot for preview and QC
# - TSSigma, TOXYChlor, TurbParTrans

# %%
import yaml
import glob

import ecofocipy.io.sbe_ctd_parser as sbe_ctd_parser #<- instrument specific
import ecofocipy.io.ncCFsave as ncCFsave
import ecofocipy.metaconfig.load_config as load_config
import ecofocipy.math.geotools as geotools

# %% [markdown]
# ## At Sea NRT Processing

# %%
sample_data_dir = '/Users/bell/ecoraid/2023/CTDcasts/dy2306/' #root path to cruise directory
ecofocipy_dir = '/Users/bell/Programs/EcoFOCIpy/'

# %%
###############################################################
# edit to point to {cruise sepcific} raw datafiles 
datafile = sample_data_dir+'rawconverted/' #<- point to cruise and process all files within
cruise_name = 'DY2306' #no hyphens
inst_meta_file = sample_data_dir+'logs/FOCI_standard_CTD.yaml'
###############################################################

#init and load data
cruise = sbe_ctd_parser.sbe9_11p()
filename_list = sorted(glob.glob(datafile + '*.cnv'))

(cruise_data,cruise_header) = cruise.parse(filename_list)

# %%
#this line adds available NMEA data to csv files for NRT/Preliminary erddap hosting... if there isn't an NMEA string, you will have to pull the locations
#  from the cast logs and output either a .nc or a more elaborate csv file furthur in to this process
NMEA_location = True
verbose = False

if NMEA_location:
    
    for cast in cruise_header.keys():
        cruise_data[cast][['time','latitude','longitude','profileid']] = ('0',0,0,'0')
        cruise_data[cast][['time','latitude','longitude','profileid']] = (cruise_header[cast]['NMEAtime'],
              geotools.latlon_convert(cruise_header[cast]['NMEALat'],cruise_header[cast]['NMEALon'])[0],
              geotools.latlon_convert(cruise_header[cast]['NMEALat'],cruise_header[cast]['NMEALon'])[1],
              cast.split('.')[0])
        if verbose:
            print(cruise_header[cast]['NMEAtime'],
                  geotools.latlon_convert(cruise_header[cast]['NMEALat'],cruise_header[cast]['NMEALon'])[0],
                  geotools.latlon_convert(cruise_header[cast]['NMEALat'],cruise_header[cast]['NMEALon'])[1])

# %%
#save downcast csv to file for viewing - really this is just a cleaned up cnv file
import pandas as pd
for cast in cruise_data.keys():
#     print(f'Processing Cast {cast}')
    cruise_data[cast]['time'] = pd.to_datetime(cruise_data[cast]['time'])
    cruise_data[cast].to_csv(sample_data_dir+cast.replace('cnv','csv'))

# %% [markdown]
# ## Post Cruise Processing with additional meta information

# %%
###############################################################
# edit to point to {cruise sepcific} raw datafiles 
datafile = sample_data_dir+'rawconverted/' #<- point to cruise and process all files within
cruise_name = 'DY2306' #no hyphens
cruise_meta_file = sample_data_dir+'logs/DY2306.yaml'
inst_meta_file = sample_data_dir+'logs/FOCI_standard_CTD.yaml'
group_meta_file = ecofocipy_dir+'staticdata/institutional_meta_example_ctd.yaml'
inst_shortname = '' #keep as placeholder for now
###############################################################

#init and load data
cruise = sbe_ctd_parser.sbe9_11p()
filename_list = sorted(glob.glob(datafile + '*.cnv'))

(cruise_data,cruise_header) = cruise.parse(filename_list)

# %% [markdown]
# ## Time Properties
#
# Not traditionally dealt with for CTD files as they are likely dynamically updated via GPS feed.  However, FOCI tends to label the date/time with the ***at depth*** time-stamp
#
# ## Depth Properties and other assumptions
#
# - currently, all processing and binning (1m for FOCI) is done via seabird routines and the windows software.  This may change with the python ctd package for a few tasks

# %% [markdown]
# ## Load all external meta information

# %%
#cruise info
with open(cruise_meta_file) as file:
    cruise_config = yaml.full_load(file)

#instrument info
with open(inst_meta_file) as file:
    inst_config = yaml.full_load(file)

#institutional info
with open(group_meta_file) as file:
    group_config = yaml.full_load(file)

# %%
inst_config
# Out:
# {'time': {'epic_key': 'TIM_601',
#   'name': 'time',
#   'generic_name': 'time',
#   'standard_name': 'time',
#   'long_name': 'date and time since reference time'},
#  'depth': {'epic_key': 'D_3',
#   'generic_name': 'depth',
#   'units': 'meter',
#   'long_name': 'depth below surface (meters)',
#   'standard_name': 'depth',
#   'positive': 'down'},
#  'latitude': {'epic_key': 'LON_501',
#   'name': 'latitude',
#   'generic_name': 'latitude',
#   'units': 'degrees_north',
#   'long_name': 'latitude',
#   'standard_name': 'latitude'},
#  'longitude': {'epic_key': 'LAT_500',
#   'name': 'longitude',
#   'generic_name': 'longitude',
#   'units': 'degrees_east',
#   'long_name': 'longitude',
#   'standard_name': 'longitude'},
#  'temperature_ch1': {'epic_key': 'T_28',
#   'generic_name': 'temp channel 1',
#   'long_name': 'Sea temperature in-situ ITS-90 scale',
#   'standard_name': 'sea_water_temperature',
#   'units': 'degree_C'},
#  'temperature_ch2': {'epic_key': 'T2_35',
#   'generic_name': 'temp channel 2',
#   'long_name': 'Sea temperature in-situ ITS-90 scale',
#   'standard_name': 'sea_water_temperature',
#   'units': 'degree_C'},
#  'pressure': {'epic_key': 'P_1',
#   'generic_name': 'pres',
#   'units': 'decibar',
#   'long_name': 'Sea water pressure, equals 0 at sea-level',
#   'standard_name': 'sea_water_pressure_due_to_sea_water'},
#  'salinity_ch1': {'epic_key': 'S_41',
#   'generic_name': 'psal channel 1',
#   'units': 'PSU',
#   'long_name': 'Practical salinity in-situ PSS-78 scale',
#   'standard_name': 'sea_water_practical_salinity'},
#  'salinity_ch2': {'epic_key': 'S_42',
#   'generic_name': 'psal channel 2',
#   'units': 'PSU',
#   'long_name': 'Practical salinity in-situ PSS-78 scale',
#   'standard_name': 'sea_water_practical_salinity'},
#  'chlor_fluorescence': {'epic_key': 'F_903',
#   'generic_name': 'chlor_fluorescence',
#   'long_name': 'Mass Concdentration of chlorophyll from chlorophyll fluorescence',
#   'standard_name': 'mass_concentration_of_chlorophyll_in_sea_water',
#   'units': 'ugrams/l'},
#  'turbidity': {'epic_key': 'Trb_980',
#   'generic_name': 'Turbidity',
#   'long_name': 'Turbidity of ocean water in Nephlometric Turbidity Units',
#   'standard_name': 'sea_water_turbidity',
#   'units': 'NTU'},
#  'par': {'generic_name': 'par',
#   'epic_key': 'PAR_905',
#   'long_name': 'Photosynthetic Active Radiation',
#   'standard_name': 'omnidirectional_photosynthetic_photon_spherical_irradiance_in_sea_water',
#   'units': 'uEin cm-2 s-1'},
#  'oxy_conc_ch1': {'generic_name': 'oxy_conc channel 1',
#   'epic_key': 'O_65',
#   'long_name': 'concentration of oxygen in seawater',
#   'standard_name': 'mole_concentration_of_dissolved_molecular_oxygen_in_sea_water',
#   'units': 'micromole/kg'},
#  'oxy_conc_ch2': {'generic_name': 'oxy_conc channel 2',
#   'epic_key': 'CTDOXY_4221',
#   'long_name': 'concentration of oxygen in seawater',
#   'standard_name': 'mole_concentration_of_dissolved_molecular_oxygen_in_sea_water',
#   'units': 'micromole/kg'},
#  'oxy_concM_ch1': {'generic_name': 'oxy_concM channel 1',
#   'epic_key': 'O_65',
#   'long_name': 'concentration of oxygen in seawater',
#   'standard_name': 'mole_concentration_of_dissolved_molecular_oxygen_in_sea_water',
#   'units': 'ml/l'},
#  'oxy_concM_ch2': {'generic_name': 'oxy_concM channel 2',
#   'epic_key': 'O_2060',
#   'long_name': 'concentration of oxygen in seawater',
#   'standard_name': 'mole_concentration_of_dissolved_molecular_oxygen_in_sea_water',
#   'units': 'ml/l'},
#  'oxy_percentsat_ch1': {'generic_name': 'oxy_psat channel 1',
#   'epic_key': 'OST_62',
#   'units': 'percent',
#   'long_name': 'Percent Saturation of oxygen over air',
#   'standard_name': 'fractional_saturation_of_oxygen_in_sea_water'},
#  'oxy_percentsat_ch2': {'generic_name': 'oxy_psat channel 2',
#   'epic_key': 'CTDOST_4220',
#   'units': 'percent',
#   'long_name': 'Percent Saturation of oxygen over air',
#   'standard_name': 'fractional_saturation_of_oxygen_in_sea_water'}}

# %%
cruise_config['CTDCasts']['CTD001']
# Out:
# {'id': 54144,
#  'Vessel': 'NOAAS Oscar Dyson',
#  'CruiseID': 'DY2306',
#  'Project_Leg': '',
#  'UniqueCruiseID': 'DY2306',
#  'Project': 'EcoFOCI Spring Mooring Cruise',
#  'StationNo_altname': 's1h1',
#  'ConsecutiveCastNo': 'CTD001',
#  'LatitudeDeg': 54,
#  'LatitudeMin': 50.17,
#  'LongitudeDeg': 158,
#  'LongitudeMin': 58.97,
#  'GMTDay': 23,
#  'GMTMonth': 'Apr',
#  'GMTYear': 2023,
#  'GMTTime': 23580,
#  'DryBulb': 5.5,
#  'RelativeHumidity': 54,
#  'WetBulb': -99.9,
#  'Pressure': 1017,
#  'SeaState': '',
#  'Visibility': '',
#  'WindDir': 309,
#  'WindSpd': 24.0,
#  'CloudAmt': '',
#  'CloudType': '',
#  'Weather': '',
#  'SurfaceTemp': -99.9,
#  'BottomDepth': 74,
#  'StationNameID': 'Shumagins',
#  'MaxDepth': 65,
#  'InstrumentSerialNos': '',
#  'Notes': '',
#  'NutrientBtlNiskinNo': '',
#  'NutrientBtlNumbers': '',
#  'OxygenBtlNiskinNo': '1',
#  'OxygenBtlNumbers': '244',
#  'SalinityBtlNiskinNo': '1',
#  'SalinityBtlNumbers': '121',
#  'ChlorophyllBtlNiskinNo': '',
#  'ChlorophyllBtlVolumes': '',
#  'InstrumentType': 'SBE911plus',
#  'WaterMassCode': 'G',
#  'isMooringProfileCast': 'n',
#  'MooringID': '',
#  'QualityControlled': 'n',
#  'FileName': ''}

# %%
cruise_data['ctd001.cnv'].columns
# Out:
# Index(['c0mS/cm', 'c1mS/cm', 'flECO-AFL', 'sbeox0V', 't090C', 't190C', 'timeS',
#        'turbWETntu0', 'sbeox1V', 'v6', 'par', 'sal00', 'sal11', 'sigma-t00',
#        'sigma-t11', 'sbeox0ML/L', 'sbox0Mm/Kg', 'sbeox0PS', 'sbeox1ML/L',
#        'sbox1Mm/Kg', 'sbeox1PS', 'nbin', 'flag'],
#       dtype='object')

# %%
for cast in cruise_data.keys():
    print(f'Processing Cast {cast}')
    try:
        #output cruise cast stats here
        #cruise_data[cast].describe()
        #cruise_data['ctd001.cnv'].hist() - seaborn may have a better summary plot than just a bunch of histograms
        #sns.pairplot(cruise_data[cast])

        cruise_data[cast] = cruise_data[cast].rename(columns={
                            't090C':'temperature_ch1',
                            't190C':'temperature_ch2',
                            'sal00':'salinity_ch1',
                            'sal11':'salinity_ch2',
                            'sbox0Mm/Kg':'oxy_conc_ch1',
                            'sbeox0ML/L':'oxy_concM_ch1',
                            'sbeox0PS':'oxy_percentsat_ch1',
                            'sbox1Mm/Kg':'oxy_conc_ch2',
                            'sbeox1ML/L':'oxy_concM_ch2',
                            'sbeox1PS':'oxy_percentsat_ch2',
                            'sigma-t00':'sigma_t_ch1',
                            'sigma-t11':'sigma_t_ch2',
                            'flECO-AFL':'chlor_fluorescence',
                            'turbWETntu0':'turbidity',
                            'cstarat0':'Attenuation',
                            'cstartr0':'Transmittance',
                            'par':'par',
                            'empty':'empty', #this will be ignored
                            'flag':'flag'})

        cruise_data[cast].index.rename('depth',inplace=True)
        #cruise_data[cast].sample()

        cruise_data_nc = ncCFsave.EcoFOCI_CFnc(df=cruise_data[cast], 
                                    instrument_yaml=inst_config, 
                                    operation_yaml=cruise_config,
                                    operation_type='ctd')
        cruise_data_nc.expand_dimensions(dim_names=['latitude','longitude','time'],geophys_sort=False)
        cruise_data_nc.variable_meta_data(variable_keys=list(cruise_data[cast].columns.values),drop_missing=True)
        cruise_data_nc.dimension_meta_data(variable_keys=['depth','latitude','longitude'])
        cruise_data_nc.temporal_geospatioal_meta_data_ctd(positiveE=False,conscastno=cast.split('.')[0])

        cruise_data_nc.var_qcflag_init(dim_names=['depth','latitude','longitude','time'])

        #interp to sfc for list of vars
        try:
            cruise_data_nc.interp2sfc(novars=['par'])
        except:
            pass

        #add global attributes
        cruise_data_nc.deployment_meta_add(conscastno=cast.upper().split('.')[0])
        cruise_data_nc.get_xdf()

        #add instituitonal global attributes
        cruise_data_nc.institution_meta_add(group_config)

        #add creation date/time - provenance data
        cruise_data_nc.provinance_meta_add()

        #provide intial qc status field
        cruise_data_nc.qc_status(qc_status='unknown')

        cast_label = cast.split('.')[0].split('d')[-1]
        cruise_data_nc.xarray2netcdf_save(xdf = cruise_data_nc.get_xdf(),
                                filename=sample_data_dir+cruise_name+'c'+cast_label.zfill(3)+'_ctd.nc',format="NETCDF3_CLASSIC")
        #generate editable csv files
        to_edit = True
        if to_edit:
            if not cast[0] in ['d','u']: #dont save editable up and downcast files, just nc files for plotting... all u/d files can be removed after final data
                cruise_data_nc.get_xdf().to_dataframe().to_csv(sample_data_dir+cruise_name+'c'+cast_label.zfill(3)+'_ctd.to_edit.csv')  
        
    except:
       print('Conversion Failed')
# Out:
# Processing Cast ctd001.cnv
# Processing Cast ctd002.cnv
# Processing Cast ctd003.cnv
# Processing Cast ctd004.cnv
# Processing Cast ctd005.cnv
# Processing Cast ctd006.cnv
# Processing Cast ctd007.cnv
# Processing Cast ctd008.cnv
# Processing Cast ctd009.cnv
# Processing Cast ctd010.cnv
# Processing Cast ctd011.cnv
# Processing Cast ctd012.cnv
# Processing Cast ctd013.cnv
# Processing Cast ctd014.cnv
# Processing Cast ctd015.cnv
# Processing Cast ctd016.cnv
# Processing Cast ctd017.cnv
# Processing Cast ctd018.cnv
# Processing Cast ctd019.cnv
# Processing Cast ctd020.cnv
# Processing Cast ctd021.cnv
# Processing Cast ctd022.cnv
# Processing Cast ctd023.cnv
# Processing Cast ctd024.cnv
# Processing Cast ctd025.cnv
# Processing Cast ctd026.cnv
# Processing Cast ctd027.cnv
# Conversion Failed
# Processing Cast dctd020.cnv
# Conversion Failed
# Processing Cast dctd021.cnv
# Conversion Failed
# Processing Cast dctd022.cnv
# Conversion Failed
# Processing Cast dctd023.cnv
# Conversion Failed
# Processing Cast dctd024.cnv
# Conversion Failed
# Processing Cast dctd025.cnv
# Conversion Failed
# Processing Cast dctd026.cnv
# Conversion Failed
# Processing Cast dctd027.cnv
# Conversion Failed
# Processing Cast dctd028.cnv
# Conversion Failed
# Processing Cast dctd029.cnv
# Conversion Failed
# Processing Cast dctd030.cnv
# Conversion Failed
# Processing Cast dctd031.cnv
# Conversion Failed
# Processing Cast dctd032.cnv
# Conversion Failed
# Processing Cast dctd033.cnv
# Conversion Failed
# Processing Cast dctd034.cnv
# Conversion Failed
# Processing Cast dctd035.cnv
# Conversion Failed
# Processing Cast dctd036.cnv
# Conversion Failed
# Processing Cast dctd037.cnv
# Conversion Failed
# Processing Cast dctd038.cnv
# Conversion Failed
# Processing Cast dctd039.cnv
# Conversion Failed
# Processing Cast dctd040.cnv
# Conversion Failed
# Processing Cast dctd041.cnv
# Conversion Failed
# Processing Cast dctd042.cnv
# Conversion Failed
# Processing Cast dctd043.cnv
# Conversion Failed
# Processing Cast dctd044.cnv
# Conversion Failed
# Processing Cast dctd045.cnv
# Conversion Failed
# Processing Cast dctd046.cnv
# Conversion Failed
# Processing Cast dctd047.cnv
# Conversion Failed
# Processing Cast dctd048.cnv
# Conversion Failed
# Processing Cast dctd049.cnv
# Conversion Failed
# Processing Cast dctd050.cnv
# Conversion Failed
# Processing Cast dctd051.cnv
# Conversion Failed
# Processing Cast dctd052.cnv
# Conversion Failed
# Processing Cast dctd053.cnv
# Conversion Failed
# Processing Cast dctd054.cnv
# Conversion Failed
# Processing Cast dctd055.cnv
# Conversion Failed
# Processing Cast dctd056.cnv
# Conversion Failed
# Processing Cast dctd057.cnv
# Conversion Failed
# Processing Cast dctd058.cnv
# Conversion Failed
# Processing Cast dctd059.cnv
# Conversion Failed
# Processing Cast dctd060.cnv
# Conversion Failed
# Processing Cast dctd061.cnv
# Conversion Failed
# Processing Cast dctd062.cnv
# Conversion Failed
# Processing Cast dctd063.cnv
# Conversion Failed
# Processing Cast dctd064.cnv
# Conversion Failed
# Processing Cast dctd065.cnv
# Conversion Failed
# Processing Cast dctd066.cnv
# Conversion Failed
# Processing Cast dctd067.cnv
# Conversion Failed
# Processing Cast dctd068.cnv
# Conversion Failed
# Processing Cast dctd069.cnv
# Conversion Failed
# Processing Cast dctd070.cnv
# Conversion Failed
# Processing Cast dctd071.cnv
# Conversion Failed
# Processing Cast dctd072.cnv
# Conversion Failed
# Processing Cast dctd073.cnv
# Conversion Failed
# Processing Cast dctd074.cnv
# Conversion Failed
# Processing Cast dctd075.cnv
# Conversion Failed
# Processing Cast dctd076.cnv
# Conversion Failed
# Processing Cast dctd077.cnv
# Conversion Failed
# Processing Cast dctd078.cnv
# Conversion Failed
# Processing Cast dctd079.cnv
# Conversion Failed
# Processing Cast dctd080.cnv
# Conversion Failed
# Processing Cast dctd081.cnv
# Conversion Failed
# Processing Cast dctd082.cnv
# Conversion Failed
# Processing Cast dctd083.cnv
# Conversion Failed
# Processing Cast dctd084.cnv
# Conversion Failed
# Processing Cast dctd085.cnv
# Conversion Failed
# Processing Cast dctd086.cnv
# Conversion Failed
# Processing Cast dctd087.cnv
# Conversion Failed
# Processing Cast dctd088.cnv
# Conversion Failed
# Processing Cast uctd001.cnv
# Conversion Failed
# Processing Cast uctd002.cnv
# Conversion Failed
# Processing Cast uctd003.cnv
# Conversion Failed
# Processing Cast uctd004.cnv
# Conversion Failed
# Processing Cast uctd005.cnv
# Conversion Failed
# Processing Cast uctd006.cnv
# Conversion Failed
# Processing Cast uctd007.cnv
# Conversion Failed
# Processing Cast uctd008.cnv
# Conversion Failed
# Processing Cast uctd009.cnv
# Conversion Failed
# Processing Cast uctd010.cnv
# Conversion Failed
# Processing Cast uctd011.cnv
# Conversion Failed
# Processing Cast uctd012.cnv
# Conversion Failed
# Processing Cast uctd013.cnv
# Conversion Failed
# Processing Cast uctd014.cnv
# Conversion Failed
# Processing Cast uctd015.cnv
# Conversion Failed
# Processing Cast uctd016.cnv
# Conversion Failed
# Processing Cast uctd017.cnv
# Conversion Failed
# Processing Cast uctd018.cnv
# Conversion Failed
# Processing Cast uctd019.cnv
# Conversion Failed
# Processing Cast uctd020.cnv
# Conversion Failed
# Processing Cast uctd021.cnv
# Conversion Failed
# Processing Cast uctd022.cnv
# Conversion Failed
# Processing Cast uctd023.cnv
# Conversion Failed
# Processing Cast uctd024.cnv
# Conversion Failed
# Processing Cast uctd025.cnv
# Conversion Failed
# Processing Cast uctd026.cnv
# Conversion Failed
# Processing Cast uctd027.cnv
# Conversion Failed
# Processing Cast uctd028.cnv
# Conversion Failed
# Processing Cast uctd029.cnv
# Conversion Failed
# Processing Cast uctd030.cnv
# Conversion Failed
# Processing Cast uctd031.cnv
# Conversion Failed
# Processing Cast uctd032.cnv
# Conversion Failed
# Processing Cast uctd033.cnv
# Conversion Failed
# Processing Cast uctd034.cnv
# Conversion Failed
# Processing Cast uctd035.cnv
# Conversion Failed
# Processing Cast uctd036.cnv
# Conversion Failed
# Processing Cast uctd037.cnv
# Conversion Failed
# Processing Cast uctd038.cnv
# Conversion Failed
# Processing Cast uctd039.cnv
# Conversion Failed
# Processing Cast uctd040.cnv
# Conversion Failed
# Processing Cast uctd041.cnv
# Conversion Failed
# Processing Cast uctd042.cnv
# Conversion Failed
# Processing Cast uctd043.cnv
# Conversion Failed
# Processing Cast uctd044.cnv
# Conversion Failed
# Processing Cast uctd045.cnv
# Conversion Failed
# Processing Cast uctd046.cnv
# Conversion Failed
# Processing Cast uctd047.cnv
# Conversion Failed
# Processing Cast uctd048.cnv
# Conversion Failed
# Processing Cast uctd049.cnv
# Conversion Failed
# Processing Cast uctd050.cnv
# Conversion Failed
# Processing Cast uctd051.cnv
# Conversion Failed
# Processing Cast uctd052.cnv
# Conversion Failed
# Processing Cast uctd053.cnv
# Conversion Failed
# Processing Cast uctd054.cnv
# Conversion Failed
# Processing Cast uctd055.cnv
# Conversion Failed
# Processing Cast uctd056.cnv
# Conversion Failed
# Processing Cast uctd057.cnv
# Conversion Failed
# Processing Cast uctd058.cnv
# Conversion Failed
# Processing Cast uctd059.cnv
# Conversion Failed
# Processing Cast uctd060.cnv
# Conversion Failed
# Processing Cast uctd061.cnv
# Conversion Failed
# Processing Cast uctd062.cnv
# Conversion Failed
# Processing Cast uctd063.cnv
# Conversion Failed
# Processing Cast uctd064.cnv
# Conversion Failed
# Processing Cast uctd065.cnv
# Conversion Failed
# Processing Cast uctd066.cnv
# Conversion Failed
# Processing Cast uctd067.cnv
# Conversion Failed
# Processing Cast uctd068.cnv
# Conversion Failed
# Processing Cast uctd069.cnv
# Conversion Failed
# Processing Cast uctd070.cnv
# Conversion Failed
# Processing Cast uctd071.cnv
# Conversion Failed
# Processing Cast uctd072.cnv
# Conversion Failed
# Processing Cast uctd073.cnv
# Conversion Failed
# Processing Cast uctd074.cnv
# Conversion Failed
# Processing Cast uctd075.cnv
# Conversion Failed
# Processing Cast uctd076.cnv
# Conversion Failed
# Processing Cast uctd077.cnv
# Conversion Failed
# Processing Cast uctd078.cnv
# Conversion Failed
# Processing Cast uctd079.cnv
# Conversion Failed
# Processing Cast uctd080.cnv
# Conversion Failed
# Processing Cast uctd081.cnv
# Conversion Failed
# Processing Cast uctd082.cnv
# Conversion Failed
# Processing Cast uctd083.cnv
# Conversion Failed
# Processing Cast uctd084.cnv
# Conversion Failed
# Processing Cast uctd085.cnv
# Conversion Failed
# Processing Cast uctd086.cnv
# Conversion Failed
# Processing Cast uctd087.cnv
# Conversion Failed
# Processing Cast uctd088.cnv
# Conversion Failed

# %% [markdown]
# ## QC Next Steps

# %%
import ecofocipy.plots.sbe_ctd_plots as sbe_ctd_plots
import os
import xarray as xa
import seaborn as sns
import numpy as np

# %%
sample_data_dir = '/Users/bell/ecoraid/2023/CTDcasts/dy2306/working/' #root path to cruise directory working repo

# %% [markdown]
# ### QC of data (plot parameters with other instruments)
# - be sure to updated the qc_status for the file and the history for future steps
# - from NRT csv files... make edits then use that to modify netcdf?
# - **Better Yet** export netcdf files with variable flags to csv and edit then reingest and modify
#     - modify netcdf in place and provide a qcflag?
#
#
# ### Likely first edits
# - research issues noted in cruise logs
# - remove failed instrument (clogs, or other challenges that arent correctable)
# - extrapolate to sfc (not par though)
# - despike depths (interpolate between depths)
# - check for common issues
#     - lags in salinity when going through interface

# %%
#test for salinity bottle run needs
for cast in sorted(os.listdir(sample_data_dir)):
    if cast.endswith('.nc'):
        try:
            cruise_data_nc = xa.load_dataset(sample_data_dir+cast)
            saldiff = cruise_data_nc.salinity_ch1 - cruise_data_nc.salinity_ch2
            print(f"{cast}: Profile Averaged Salinity Difference,STD (chan1-chan2){saldiff.mean().values},{saldiff.std().values}")        
            saldiff.plot.hist(bins=50,xlim=[-.005,.005])
        except:
            print(f"{cast}: less than two salinity channels")
# Out:
# DY2306c001_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)-0.0023573529411760968,0.00040884204359270803
# DY2306c002_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)-0.003473509933774668,0.002763592584256164
# DY2306c003_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)-0.003046296296296368,0.00013431990967231928
# DY2306c004_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)-0.002470072992700782,0.007273874508103064
# DY2306c005_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)-0.003530674846626017,0.0008703945433805191
# DY2306c006_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)-0.003320000000000239,0.0011244152602211607
# DY2306c007_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)-0.0029429175475684764,0.00047526285991394393
# DY2306c008_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)-0.002678431372548991,0.001217779033610827
# DY2306c009_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)-0.
ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)-0.0025704918032786964,0.0025858596732870635
# DY2306c065_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)-0.0031955223880597307,0.00038957797135771686
# DY2306c066_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)-0.0028782608695653573,0.0004078467903648202
# DY2306c067_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)-0.0027615384615385843,0.0003076923076927657
# DY2306c068_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)-0.0030999999999994964,0.0003136532773274743
# DY2306c069_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)-0.0029878048780484895,0.0009144357508406469
# DY2306c070_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)-0.0031609756097560095,0.00025555110107121224
# DY2306c071_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)-0.003417500000000473,0.0002508859302554796
# DY2306c072_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)-0.0031615384615389275,0.000263716421719652
# DY2306c073_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)-0.003055263157894815,0.001414529374669334
# DY2306c074_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)-0.002513043478260728,0.0007069864692304976
# DY2306c075_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)-0.0031246153846144972,0.0004191679557736386
# DY2306c076_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)-0.0031894117647058053,0.0005784408108235715
# DY2306c077_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)-0.00336853932584267,0.0008066570642105055
# DY2306c078_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)-0.004212315270936171,0.0006497411831166731
# DY2306c079_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)-0.003964051094890576,0.001106947046525953
# DY2306c080_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)-0.004277741300065469,0.0002608328371288863
# DY2306c081_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)-0.008848839907192605,0.05528018942805611
# DY2306c082_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)-0.0024295839753467508,0.002673816425996408
# DY2306c083_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)-0.003376748971193331,0.0030988472778419227
# DY2306c084_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)-0.004652224824355755,0.005576192573933111
# DY2306c085_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)-0.00333896761133605,0.003462834740533542
# DY2306c086_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)-0.0022294212218650737,0.003294483255724866
# DY2306c087_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)-0.004195867768594923,0.0008686835003826069
# DY2306c088_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)-0.0029270787343634542,0.001788258553821789

# %%
# Following routines will eventually get ported to ecofocipy as subroutines to be called

import seawater as sw

def sigmat_update(salinity=None,temperature=None):
    '''
    Changes to T or S (commonly to despike values or apply a salinity offset) will need corresponding changes in sigmat
    '''
    # calculate sigmaT at 0db gauge pressure (s, t, p=0)
    sigt = (sw.eos80.dens0(s=salinity, t=temperature) - 1000)
    
    return sigt

# %% [markdown]
# ## Generate Plots
#
#
# ### Make General Plots
# - 1:1 plots for paired instruments for each cast (tells if a sensor failed)
# - TS_Sigmat, Chlor/Par/Turb, Oxy,Temp
# - T/S property property plot
# - upcast/downcast plt

# %%
calc_sigmat = True

for cast in sorted(os.listdir(sample_data_dir)):
    if cast.endswith('.nc'):
        cruise_data_nc = xa.load_dataset(sample_data_dir+cast)
        ctd_df = cruise_data_nc.to_dataframe()
        
        if calc_sigmat:
            #update sigmat (or calculate it I suppose)
            sigup = sigmat_update(salinity=ctd_df.salinity_ch1,
                                  temperature=ctd_df.temperature_ch1)
            ctd_df['sigma_t_ch1'] = sigup
            
            sigup2 = sigmat_update(salinity=ctd_df.salinity_ch2,
                                  temperature=ctd_df.temperature_ch2)
            ctd_df['sigma_t_ch2'] = sigup2   
        sbe_p = sbe_ctd_plots.CTDProfilePlot()
        plt,fig =sbe_p.plot3var(varname=['temperature_ch1','temperature_ch2','salinity_ch1','salinity_ch2','sigma_t_ch1','sigma_t_ch2'],
                          xdata=[ctd_df.temperature_ch1,ctd_df.temperature_ch2,ctd_df.salinity_ch1,ctd_df.salinity_ch2,ctd_df.sigma_t_ch1,ctd_df.sigma_t_ch2],
                          ydata=ctd_df.index.get_level_values('depth'),
                          secondary=True,
                          xlabel=['Temperature','Salinity','Sigma-T'])

        DefaultSize = fig.get_size_inches()
        fig.set_size_inches( (DefaultSize[0], DefaultSize[1]*3) )
        plt.savefig(sample_data_dir+cast.replace('.nc','_TempSalSigmat.png'))
        plt.close(fig)

# %%
for cast in sorted(os.listdir(sample_data_dir)):
    if cast.endswith('.nc'):
        cruise_data_nc = xa.load_dataset(sample_data_dir+cast)
        ctd_df = cruise_data_nc.to_dataframe()
        
        sbe_p = sbe_ctd_plots.CTDProfilePlot()
        plt,fig =sbe_p.plot2var(varname=['temperature_ch1','temperature_ch2','oxy_percentsat_ch1','oxy_percentsat_ch2'],
                          xdata=[ctd_df.temperature_ch1,ctd_df.temperature_ch2,ctd_df.oxy_percentsat_ch1,ctd_df.oxy_percentsat_ch2],
                          ydata=ctd_df.index.get_level_values('depth'),
                          secondary=True,
                          xlabel=['Temperature','Oxygen Saturation'])

        DefaultSize = fig.get_size_inches()
        fig.set_size_inches( (DefaultSize[0], DefaultSize[1]*3) )
        plt.savefig(sample_data_dir+cast.replace('.nc','_TempOxy.png'))
        plt.close(fig)

# %%
for cast in sorted(os.listdir(sample_data_dir)):
    if cast.endswith('.nc'):
        cruise_data_nc = xa.load_dataset(sample_data_dir+cast)
        ctd_df = cruise_data_nc.to_dataframe()
        
        sbe_p = sbe_ctd_plots.CTDProfilePlot()
        plt,fig =sbe_p.plot3var(varname=['turbidity','','chlor_fluorescence','','par'],
                          xdata=[ctd_df.turbidity,np.array([]),ctd_df.chlor_fluorescence,np.array([]),ctd_df.par,np.array([])],
                          ydata=ctd_df.index.get_level_values('depth'),
                          secondary=False,
                          xlabel=['Turbidity','Fluor','Par'])

        DefaultSize = fig.get_size_inches()
        fig.set_size_inches( (DefaultSize[0], DefaultSize[1]*3) )
        plt.savefig(sample_data_dir+cast.replace('.nc','_TurbFluorPAR.png'))
        plt.close(fig)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[29], line 8
#       4 ctd_df = cruise_data_nc.to_dataframe()
#       6 sbe_p = sbe_ctd_plots.CTDProfilePlot()
#       7 plt,fig =sbe_p.plot3var(varname=['turbidity','','chlor_fluorescence','','par'],
# ----> 8                   xdata=[ctd_df.turbidity,np.array([]),ctd_df.chlor_fluorescence,np.array([]),ctd_df.par,np.array([])],
#       9                   ydata=ctd_df.index.get_level_values('depth'),
#      10                   secondary=False,
#      11                   xlabel=['Turbidity','Fluor','Par'])
#      13 DefaultSize = fig.get_size_inches()
#      14 fig.set_size_inches( (DefaultSize[0], DefaultSize[1]*3) )
#
# File ~/miniconda3/envs/py310/lib/python3.10/site-packages/pandas/core/generic.py:5989, in NDFrame.__getattr__(self, name)
#    5982 if (
#    5983     name not in self._internal_names_set
#    5984     and name not in self._metadata
#    5985     and name not in self._accessors
#    5986     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987 ):
#    5988     return self[name]
# -> 5989 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'par'

# %% [markdown]
# # Cross Sections

# %%
#cruise_data_nc.get_xdf().to_dataframe().columns
sns.pairplot(cruise_data_nc.to_dataframe()[['salinity_ch1', 'salinity_ch2',]])

# %%
# ## Export data from nc files
# for cast in sorted(os.listdir(sample_data_dir+'working/')):
#     if cast.endswith('.nc'):
#         cruise_data_nc = xa.load_dataset(sample_data_dir+'working/'+cast)
#         cruise_data_nc.to_dataframe().to_csv(sample_data_dir+'working/'+cast.replace('.nc','.to_edit.csv') )
