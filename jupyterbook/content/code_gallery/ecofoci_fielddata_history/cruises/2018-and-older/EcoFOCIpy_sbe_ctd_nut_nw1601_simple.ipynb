# %% [markdown]
# # Using EcoFOCIpy to process raw field data
#
# ## ____ Template for cruise (pre 2020)
#
# ## BTL Data + Nutrient Data
#
# This is a streamlined version of generation routines to merge bottle data and Mordy Nut. Lab Nutrient Data for long term archive

# %% [markdown]
# <div class="warning" style='background-color:#E9D8FD; color: #69337A; border-left: solid #805AD5 4px; border-radius: 4px; padding:0.7em;'>
# <span>
# <p style='margin-top:1em; text-align:center'>
# <b>A template for Nutrient Lab ASCII files to NETCDF</b></p>
# <p style='margin-left:1em;'>
# Populate the necessary paths in the following cells.</p>
# <p style='margin-bottom:1em; margin-right:1em; text-align:right; font-family:Georgia'> <b>- Shaun Bell</b>
# </p></span>
# </div>

# %%
import yaml
import glob
import pandas as pd
import os

import ecofocipy.io.sbe_ctd_parser as sbe_ctd_parser #<- instrument specific
import ecofocipy.io.ncCFsave as ncCFsave
import ecofocipy.metaconfig.load_config as load_config

# %%
sample_data_dir = '/Users/bell/ecoraid/2012/CTDcasts/nw1202/' #root path to cruise directory
ecofocipy_dir = '/Users/bell/Programs/EcoFOCIpy/'

# %%
###############################################################
# edit to point to {cruise sepcific} raw datafiles 
datafile = sample_data_dir+'rawconverted/' #<- point to cruise and process all files within
datafile = '/Users/bell/ecoraid/2013/CTDcasts/nw1301/original_archive_from_krafla/btl/original_files/' #<- point to cruise and process all files within
nutdatafile = sample_data_dir+'working/DiscreteNutrients/NW1301 Nutrient Data.txt' #<- point to cruise and process all files within
cruise_name = 'nw1301' #no hyphens
cruise_meta_file = sample_data_dir+'logs/NW1301.yaml'
inst_meta_file = sample_data_dir+'logs/FOCI_standard_CTDpNuts.yaml' #<- copy to each deployment for simplicity?
group_meta_file = ecofocipy_dir+'staticdata/institutional_meta_example.yaml'
###############################################################
#init and load data
cruise = sbe_ctd_parser.sbe_btl()
filename_list = sorted(glob.glob(datafile + '*.btl'))

cruise_data = cruise.manual_parse(filename_list)
# Out:
# Processing /Users/bell/ecoraid/2012/CTDcasts/nw1201/original_archive_from_krafla/btl/original_files/ctd001.btl
# Processing /Users/bell/ecoraid/2012/CTDcasts/nw1201/original_archive_from_krafla/btl/original_files/ctd002.btl
# Processing /Users/bell/ecoraid/2012/CTDcasts/nw1201/original_archive_from_krafla/btl/original_files/ctd003.btl
# Processing /Users/bell/ecoraid/2012/CTDcasts/nw1201/original_archive_from_krafla/btl/original_files/ctd004.btl
# Processing /Users/bell/ecoraid/2012/CTDcasts/nw1201/original_archive_from_krafla/btl/original_files/ctd005.btl
# Processing /Users/bell/ecoraid/2012/CTDcasts/nw1201/original_archive_from_krafla/btl/original_files/ctd006.btl
# Processing /Users/bell/ecoraid/2012/CTDcasts/nw1201/original_archive_from_krafla/btl/original_files/ctd007.btl
# Processing /Users/bell/ecoraid/2012/CTDcasts/nw1201/original_archive_from_krafla/btl/original_files/ctd008.btl
# Processing /Users/bell/ecoraid/2012/CTDcasts/nw1201/original_archive_from_krafla/btl/original_files/ctd009.btl
# Processing /Users/bell/ecoraid/2012/CTDcasts/nw1201/original_archive_from_krafla/btl/original_files/ctd011.btl
# Processing /Users/bell/ecoraid/2012/CTDcasts/nw1201/original_archive_from_krafla/btl/original_files/ctd012.btl
# Processing /Users/bell/ecoraid/2012/CTDcasts/nw1201/original_archive_from_krafla/btl/original_files/ctd013.btl
# Processing /Users/bell/ecoraid/2012/CTDcasts/nw1201/original_archive_from_krafla/btl/original_files/ctd014.btl
# Processing /Users/bell/ecoraid/2012/CTDcasts/nw1201/original_archive_from_krafla/btl/original_files/ctd015.btl
# Processing /Users/bell/ecoraid/2012/CTDcasts/nw1201/original_archive_from_krafla/btl/original_files/ctd016.btl
# Processing /Users/bell/ecoraid/2012/CTDcasts/nw1201/original_archive_from_krafla/btl/original_files/ctd017.btl
# Processing /Users/bell/ecoraid/2012/CTDcasts/nw1201/original_archive_from_krafla/btl/original_files/ctd018.btl
# Processing /Users/bell/ecoraid/2012/CTDcasts/nw1201/original_archive_from_krafla/btl/original_files/ctd019.btl
# Processing /Users/bell/ecoraid/2012/CTDcasts/nw1201/original_archive_from_krafla/btl/original_files/ctd020.btl
# Processing /Users/bell/ecoraid/2012/CTDcasts/nw1201/original_archive_from_krafla/btl/original_files/ctd021.btl
# Processing /Users/bell/ecoraid/2012/CTDcasts/nw1201/original_archive_from_krafla/btl/original_files/ctd022.btl
# Processing /Users/bell/ecoraid/2012/CTDcasts/nw1201/original_archive_from_krafla/btl/original_files/ctd023.btl
# Processing /Users/bell/ecoraid/2012/CTDcasts/nw1201/original_archive_from_krafla/btl/original_files/ctd025.btl
# Processing /Users/bell/ecoraid/2012/CTDcasts/nw1201/original_archive_from_krafla/btl/original_files/ctd026.btl
# Processing /Users/bell/ecoraid/2012/CTDcasts/nw1201/original_archive_from_krafla/btl/original_files/ctd027.btl
# Processing /Users/bell/ecoraid/2012/CTDcasts/nw1201/original_archive_from_krafla/btl/original_files/ctd028.btl
# Processing /Users/bell/ecoraid/2012/CTDcasts/nw1201/original_archive_from_krafla/btl/original_files/ctd029.btl
# Processing /Users/bell/ecoraid/2012/CTDcasts/nw1201/original_archive_from_krafla/btl/original_files/ctd030.btl
# Processing /Users/bell/ecoraid/2012/CTDcasts/nw1201/original_archive_from_krafla/btl/original_files/ctd031.btl
# Processing /Users/bell/ecoraid/2012/CTDcasts/nw1201/original_archive_from_krafla/btl/original_files/ctd032.btl
# Processing /Users/bell/ecoraid/2012/CTDcasts/nw1201/original_archive_from_krafla/btl/original_files/ctd033.btl
# Processing /Users/bell/ecoraid/2012/CTDcasts/nw1201/original_archive_from_krafla/btl/original_files/ctd034.btl
# Processing /Users/bell/ecoraid/2012/CTDcasts/nw1201/original_archive_from_krafla/btl/original_files/ctd035.btl
# Processing /Users/bell/ecoraid/2012/CTDcasts/nw1201/original_archive_from_krafla/btl/original_files/ctd036.btl
# Processing /Users/bell/ecoraid/2012/CTDcasts/nw1201/original_archive_from_krafla/btl/original_files/ctd037.btl
# Processing /Users/bell/ecoraid/2012/CTDcasts/nw1201/original_archive_from_krafla/btl/original_files/ctd038.btl
# Processing /Users/bell/ecoraid/2012/CTDcasts/nw1201/original_archive_from_krafla/btl/original_files/ctd039.btl
# Processing /Users/bell/ecoraid/2012/CTDcasts/nw1201/original_archive_from_krafla/btl/original_files/ctd040.btl
# Processing /Users/bell/ecoraid/2012/CTDcasts/nw1201/original_archive_from_krafla/btl/original_files/ctd041.btl
# Processing /Users/bell/ecoraid/2012/CTDcasts/nw1201/original_archive_from_krafla/btl/original_files/ctd042.btl
# Processing /Users/bell/ecoraid/2012/CTDcasts/nw1201/original_archive_from_krafla/btl/original_files/ctd043.btl
# Processing /Users/bell/ecoraid/2012/CTDcasts/nw1201/original_archive_from_krafla/btl/original_files/ctd044.btl
# Processing /Users/bell/ecoraid/2012/CTDcasts/nw1201/original_archive_from_krafla/btl/original_files/ctd046.btl
# Processing /Users/bell/ecoraid/2012/CTDcasts/nw1201/original_archive_from_krafla/btl/original_files/ctd047.btl
# Processing /Users/bell/ecoraid/2012/CTDcasts/nw1201/original_archive_from_krafla/btl/original_files/ctd048.btl
# Processing /Users/bell/ecoraid/2012/CTDcasts/nw1201/original_archive_from_krafla/btl/original_files/ctd049.btl
# Processing /Users/bell/ecoraid/2012/CTDcasts/nw1201/original_archive_from_krafla/btl/original_files/ctd050.btl

# %%
cruise_data['ctd001.btl']
# Out:
#           sal00  sbeox0mm/kg   sbeox0ps  oxsatmm/kg  sigma-t00     prsm  \
# bottle
# 1.0     33.8687      105.847   34.67012   305.88074    26.7024  206.243
# 2.0     33.2964      180.900   59.81658   302.92449    26.1772  100.442
# 3.0     32.6098      286.664   96.19716   298.38834    25.5236   50.784
# 4.0     32.5852      291.219   98.52792   295.92454    25.4541   38.313
# 7.0     32.5514      294.154  100.90195   291.81731    25.3392   30.499
# 8.0     32.4650      289.513  102.64665   282.20453    25.0377   20.794
# 9.0     32.4259      281.965  101.44399   278.05093    24.8935    9.214
# 10.0    32.4250      280.116  100.88386   277.75737    24.8846    1.195
#
#           t090c      v1      v2      v3  cstartr0  cstarat0           par  \
# bottle
# 1.0      5.6463  4.6836  0.0096  0.0509   99.4369    0.0226  1.000000e-12
# 2.0      6.2342  4.6743  0.4340  0.0539   99.2406    0.0305  1.283300e-01
# 3.0      7.0946  4.5965  1.6260  0.1426   97.5835    0.0979  3.133900e+00
# 4.0      7.4615  4.5662  2.0474  0.2007   96.9392    0.1243  8.421900e+00
# 7.0      8.0833  4.4618  2.3759  0.3542   94.7178    0.2171  1.798100e+01
# 8.0      9.6053  4.4431  2.6892  0.2602   94.3191    0.2339  3.708800e+01
# 9.0     10.2934  4.4676  2.8546  0.1284   94.8419    0.2118  5.432300e+01
# 10.0    10.3421  4.4629  3.3728  0.1169   94.7417    0.2161  2.130400e+02
#
#         fleco-afl  turbwetntu0            datetime
# bottle
# 1.0       -0.0609       0.7455 2012-07-03 07:12:28
# 2.0       -0.0303       0.7546 2012-07-03 07:16:29
# 3.0        0.8556       0.7756 2012-07-03 07:18:19
# 4.0        1.4374       0.7892 2012-07-03 07:19:06
# 7.0        2.9722       0.8126 2012-07-03 07:19:24
# 8.0        2.0325       0.8489 2012-07-03 07:19:57
# 9.0        0.7146       0.8073 2012-07-03 07:20:29
# 10.0       0.5992       0.8079 2012-07-03 07:20:59

# %% [markdown]
# ## Load csv Nutrient File

# %%
nut_data = pd.read_csv(nutdatafile,delimiter='\t')
nut_data
# Out:
#      Cast  Niskin  PO4 (uM)  Sil (uM)  NO3 (uM)  NO2 (uM)  NH4 (uM)
# 0       1       1     2.403      55.8      34.6      0.01      0.88
# 1       1       2     1.864      35.1      25.0      0.02      0.37
# 2       1       3     1.187      19.1      11.9      0.25      1.26
# 3       1       4     1.090      18.8      11.1      0.20      1.44
# 4       1       5     1.028      17.5       9.8      0.14      0.67
# ..    ...     ...       ...       ...       ...       ...       ...
# 375    50       4     1.208      19.3       9.8      0.32      2.49
# 376    50       5     0.972      15.7       6.2      0.21      2.23
# 377    50       6     1.109      21.0       9.6      0.19      2.25
# 378    50       7     1.105      21.8       9.7      0.16      1.03
# 379    50       8     0.589      19.0       2.2      0.05      0.31
#
# [380 rows x 7 columns]

# %%
#nw1201 relable niskins
nut_data.loc[nut_data['Niskin']> 4,'Niskin'] = nut_data.loc[nut_data['Niskin']> 4,'Niskin']+2
nut_data
# Out:
#      Cast  Niskin  PO4 (uM)  Sil (uM)  NO3 (uM)  NO2 (uM)  NH4 (uM)
# 0       1       1     2.403      55.8      34.6      0.01      0.88
# 1       1       2     1.864      35.1      25.0      0.02      0.37
# 2       1       3     1.187      19.1      11.9      0.25      1.26
# 3       1       4     1.090      18.8      11.1      0.20      1.44
# 4       1       7     1.028      17.5       9.8      0.14      0.67
# ..    ...     ...       ...       ...       ...       ...       ...
# 375    50       4     1.208      19.3       9.8      0.32      2.49
# 376    50       7     0.972      15.7       6.2      0.21      2.23
# 377    50       8     1.109      21.0       9.6      0.19      2.25
# 378    50       9     1.105      21.8       9.7      0.16      1.03
# 379    50      10     0.589      19.0       2.2      0.05      0.31
#
# [380 rows x 7 columns]

# %% [markdown]
# ## Merge Bottle and Nutrient Data but drop non nutrient vars?

# %% [markdown]
# <div class="warning" style='background-color:#ffcccb; color: #FF0000; border-left: solid #805AD5 4px; border-radius: 4px; padding:0.7em;'>
# <span>
# <p style='margin-top:1em; text-align:center'>
# <b>WARNING</b></p>
# <p style='margin-left:1em;'>bottle/niskin and rosette position should be the same but can be different (example, bottles are labeled sequentially but a rosette position is skipped due to balancing or other instruments.</p>
# </div>

# %%
keep_param = ['bottle','prsm'] #sometimes prsm

for cast,cdata in cruise_data.items():
    try:
        matchcast = int((cast.split('.')[0]).lower().split('ctd')[-1])
        cruise_data[cast] = pd.merge(nut_data[nut_data['Cast']==matchcast],cdata.reset_index()[keep_param],right_on='bottle',left_on='Niskin').set_index('bottle').drop(columns=['Cast'])
    except:
        print('something is wrong')

# %% [markdown]
# ## Add Deployment meta information

# %%
#just a dictionary of dictionaries - simple
with open(cruise_meta_file) as file:
    cruise_config = yaml.full_load(file)

# %% [markdown]
# ## Add Instrument meta information
#
# Time, depth, lat, lon should be added regardless (always our coordinates) but for a mooring site its going to be a (1,1,1,t) dataset
# The variables of interest should be read from the data file and matched to a key for naming.  That key is in the inst_config file seen below and should represent common conversion names in the raw data

# %%
with open(inst_meta_file) as file:
    inst_config = yaml.full_load(file)

# %% [markdown]
# ## Add institutional meta-information

# %%
with open(group_meta_file) as file:
    group_config = yaml.full_load(file)

# %% [markdown]
# ## Save CF Netcdf files
#
# Currently stick to netcdf3 classic... but migrating to netcdf4 (default) may be no problems for most modern purposes.  Its easy enough to pass the `format` kwargs through to the netcdf api of xarray.

# %%
#loop over all casts and perform tasks shown above

for cast in cruise_data.keys():
    try:
        cruise_data[cast] = cruise_data[cast].rename(columns={
                            'Sil (uM)':'SI',
                            'PO4 (uM)':'PO4',
                            'NO2 (uM)':'NO2', 
                            'NO3 (uM)':'NO3',
                            'NH4 (uM)':'NH4',
                            'Niskin':'BTLID',
                            # 'prdm':'pressure',
                            'prsm':'depth',
                            'empty':'empty', #this will be ignored
                            'flag':'flag'})

        cruise_data_nc = ncCFsave.EcoFOCI_CFnc(df=cruise_data[cast], 
                                    instrument_yaml=inst_config, 
                                    operation_yaml=cruise_config,
                                    operation_type='ctd')

        cruise_data_nc.expand_dimensions(dim_names=['latitude','longitude','time'],geophys_sort=False)

        cruise_data_nc.variable_meta_data(variable_keys=list(cruise_data[cast].columns.values),drop_missing=False)
        #adding dimension meta needs to come after updating the dimension values... BUG?
        cruise_data_nc.dimension_meta_data(variable_keys=['time','latitude','longitude'])
        cruise_data_nc.temporal_geospatioal_meta_data_ctd(positiveE=False,conscastno=cast.split('.')[0])

        #add global attributes
        cruise_data_nc.deployment_meta_add(conscastno=cast.split('.')[0].upper())

        #add instituitonal global attributes
        cruise_data_nc.institution_meta_add(group_config)

        #add creation date/time - provenance data
        cruise_data_nc.provinance_meta_add()

        #provide intial qc status field
        cruise_data_nc.qc_status(qc_status='excellent') #<- options are unknown, excellent, probably good, mixed, unqcd

        cruise_data_nc.xarray2netcdf_save(xdf = cruise_data_nc.get_xdf(),
                                   filename=cruise_name+'c'+cast.lower().split('d')[-1].split('.')[0].zfill(3)+'_nut.nc',format="NETCDF3_CLASSIC")
    except KeyError:
        print(f'Skipping {cast}')
    except RuntimeError:
        print(f'Skipping & Removing {cast}')
        os.remove(path=cruise_name+'c'+cast.lower().split('d')[-1].split('.')[0].zfill(3)+'_nut.nc')

# %% [markdown]
# ## Next Steps
#
# QC of data (plot parameters with other instruments)
# - be sure to updated the qc_status and the history

# %%
cruise_data_nc.get_xdf()
# Out:
# <xarray.Dataset>
# Dimensions:    (bottle: 8, latitude: 1, longitude: 1, time: 1)
# Coordinates:
#   * bottle     (bottle) float64 1.0 2.0 3.0 4.0 7.0 8.0 9.0 10.0
#   * latitude   (latitude) float64 58.1
#   * longitude  (longitude) float64 -136.8
#   * time       (time) datetime64[ns] 2012-07-21T23:53:00
# Data variables:
#     BTLID      (latitude, longitude, time, bottle) int64 1 2 3 4 7 8 9 10
#     PO4        (latitude, longitude, time, bottle) float64 1.878 1.446 ... 0.589
#     SI         (latitude, longitude, time, bottle) float64 39.1 24.7 ... 19.0
#     NO3        (latitude, longitude, time, bottle) float64 24.4 16.8 ... 9.7 2.2
#     NO2        (latitude, longitude, time, bottle) float64 0.1 0.09 ... 0.05
#     NH4        (latitude, longitude, time, bottle) float64 0.2 0.43 ... 0.31
#     depth      (latitude, longitude, time, bottle) float64 182.2 101.0 ... 2.285
# Attributes: (12/44)
#     CruiseID:                      NW1201
#     CruiseID_Historic:             1NW12
#     CruiseID_Alternates:           NW1201L1
#     Project_Leg:
#     Vessel:                        NorthWest Explorer
#     ShipID:                        NW
#     ...                            ...
#     references:
#     citation:
#     acknowledgement:
#     date_created:                  2022-08-17T17:12:13Z
#     date_modified:
#     QC_indicator:                  excellent
