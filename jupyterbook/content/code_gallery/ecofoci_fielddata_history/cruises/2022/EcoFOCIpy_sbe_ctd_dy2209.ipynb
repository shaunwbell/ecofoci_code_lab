# %% [markdown]
# # Using EcoFOCIpy to process raw field data
#
# **Cruise NW2202 (NBS)**
#
# **Processed by Shaun Bell**
#
# ## CTD / Profile Data
#
# Basic workflow for each instrument grouping is *(initial archive level)*:
# - SBE workflow must happen first **done (performed on seperate windows system to convert to cnv)**
# - output initial files (pandas->csv) **ERDDAP NRT** when no meta data is added.  Good for quick analysis
#
# Other than hosting on an erddap server, the above can be done at sea
#
# For furthur processing, QC and archiving, the following tasks are to be done *(working or final data level)*:
# - Add metadata from cruise yaml files created from cast logs
# - apply any calibrations or corrections
#     + field corrections
#     + offsets
#     + spike analysis
#     + some QC were available... this would be old-school simple bounds mostly
# - save as CF netcdf via xarray or potentially csv file: so many of the steps above are optional
#     + **ERDDAP NRT** if no corrections, offsets or time bounds are applied but some meta data is (can be csv as this is useful at sea)
#     + **Working and awaiting QC** has no ERDDAP representation and is a holding spot
#     + **ERDDAP Final** fully calibrated, qc'd and populated with meta information
#
# Plot for preview and QC
# - TSSigma, TOXYChlor, TurbParTrans

# %%
import yaml
import glob

import ecofocipy.io.sbe_ctd_parser as sbe_ctd_parser #<- instrument specific
import ecofocipy.io.ncCFsave as ncCFsave
import ecofocipy.metaconfig.load_config as load_config
import ecofocipy.math.geotools as geotools

# %% [markdown]
# ## At Sea NRT Processing

# %%
sample_data_dir = '/Users/bell/ecoraid/2022/CTDcasts/dy2209/' #root path to cruise directory
ecofocipy_dir = '/Users/bell/Programs/EcoFOCIpy/'

# %%
###############################################################
# edit to point to {cruise sepcific} raw datafiles 
datafile = sample_data_dir+'rawconverted/' #<- point to cruise and process all files within
cruise_name = 'DY2209' #no hyphens
inst_meta_file = sample_data_dir+'logs/FOCI_standard_CTDplusrinko.yaml'
###############################################################

#init and load data
cruise = sbe_ctd_parser.sbe9_11p()
filename_list = sorted(glob.glob(datafile + '*.cnv'))

(cruise_data,cruise_header) = cruise.parse(filename_list)

# %%
#this line adds available NMEA data to csv files for NRT/Preliminary erddap hosting... if there isn't an NMEA string, you will have to pull the locations
#  from the cast logs and output either a .nc or a more elaborate csv file furthur in to this process
NMEA_location = False
verbose = True

if NMEA_location:
    
    for cast in cruise_header.keys():
        cruise_data[cast][['time','latitude','longitude','profileid']] = ('0',0,0,'0')
        cruise_data[cast][['time','latitude','longitude','profileid']] = (cruise_header[cast]['NMEAtime'],
              geotools.latlon_convert(cruise_header[cast]['NMEALat'],cruise_header[cast]['NMEALon'])[0],
              geotools.latlon_convert(cruise_header[cast]['NMEALat'],cruise_header[cast]['NMEALon'])[1],
              cast.split('.')[0])
        if verbose:
            print(cruise_header[cast]['NMEAtime'],
                  geotools.latlon_convert(cruise_header[cast]['NMEALat'],cruise_header[cast]['NMEALon'])[0],
                  geotools.latlon_convert(cruise_header[cast]['NMEALat'],cruise_header[cast]['NMEALon'])[1])

# %%
#save downcast csv to file for viewing - really this is just a cleaned up cnv file
import pandas as pd
for cast in cruise_data.keys():
#     print(f'Processing Cast {cast}')
    # cruise_data[cast]['time'] = pd.to_datetime(cruise_data[cast]['time'])
    cruise_data[cast].to_csv(sample_data_dir+cast.replace('cnv','csv'))

# %%
cruise_data[cast].columns
# Out:
# Index(['c0mS/cm', 'c1mS/cm', 'flECO-AFL', 'sbeox0V', 't090C', 't190C', 'timeS',
#        'turbWETntu0', 'sbeox1V', 'upoly0', 'v6', 'par', 'sal00', 'sal11',
#        'sigma-t00', 'sigma-t11', 'sbeox0ML/L', 'sbox0Mm/Kg', 'sbeox0PS',
#        'sbeox1ML/L', 'sbox1Mm/Kg', 'sbeox1PS', 'nbin', 'flag'],
#       dtype='object')

# %% [markdown]
# ## Range Check

# %%
range_summary = pd.DataFrame()

for cast in cruise_data.keys():
    if (not cast.startswith('u')) and (not cast.startswith('d')):
        cast_range = cruise_data[cast].describe().loc[['min','max']][['flECO-AFL', 'sbeox0V', 't090C', 't190C', 'timeS',
                                                                       'turbWETntu0', 'sbeox1V', 'upoly0', 'v6', 'par', 'sal00', 'sal11',
                                                                       'sigma-t00', 'sigma-t11', 'sbeox0ML/L', 'sbox0Mm/Kg', 'sbeox0PS',
                                                                       'sbeox1ML/L', 'sbox1Mm/Kg', 'sbeox1PS',]]
        cast_range['cast'] = cast
        range_summary = pd.concat([range_summary,cast_range],ignore_index=True)

# %%
pd.set_option('display.max_rows', None)

def make_pretty(styler):
    styler.background_gradient(axis=0, cmap="YlGnBu_r")
    return styler

range_summary.style.pipe(make_pretty)
# Out:
# <style type="text/css">
# #T_302e9_row0_col0, #T_302e9_row0_col4, #T_302e9_row0_col9, #T_302e9_row2_col1, #T_302e9_row2_col6, #T_302e9_row2_col9, #T_302e9_row2_col10, #T_302e9_row2_col11, #T_302e9_row2_col12, #T_302e9_row2_col13, #T_302e9_row2_col14, #T_302e9_row2_col15, #T_302e9_row2_col16, #T_302e9_row2_col17, #T_302e9_row2_col18, #T_302e9_row2_col19, #T_302e9_row4_col2, #T_302e9_row4_col3, #T_302e9_row4_col5, #T_302e9_row4_col7, #T_302e9_row4_col9, #T_302e9_row6_col5, #T_302e9_row6_col8, #T_302e9_row6_col9, #T_302e9_row8_col9 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_302e9_row0_col1 {
#   background-color: #37acc3;
#   color: #f1f1f1;
# }
# #T_302e9_row0_col2, #T_302e9_row0_col3, #T_302e9_row0_col7, #T_302e9_row1_col6 {
#   background-color: #6dc6be;
#   color: #000000;
# }
# #T_302e9_row0_col5, #T_302e9_row0_col6, #T_302e9_row0_col19 {
#   background-color: #253896;
#   color: #f1f1f1;
# }
# #T_302e9_row0_col8 {
#   background-color: #234b9f;
#   color: #f1f1f1;
# }
# #T_302e9_row0_col10 {
#   background-color: #40b5c4;
#   color: #f1f1f1;
# }
# #T_302e9_row0_col11 {
#   background-color: #3fb4c4;
#   color: #f1f1f1;
# }
# #T_302e9_row0_col12, #T_302e9_row2_col4 {
#   background-color: #1e86bb;
#   color: #f1f1f1;
# }
# #T_302e9_row0_col13 {
#   background-color: #1e83ba;
#   color: #f1f1f1;
# }
# #T_302e9_row0_col14, #T_302e9_row0_col15 {
#   background-color: #1e8bbd;
#   color: #f1f1f1;
# }
# #T_302e9_row0_col16, #T_302e9_row3_col6, #T_302e9_row7_col8 {
#   background-color: #32a6c2;
#   color: #f1f1f1;
# }
# #T_302e9_row0_col17, #T_302e9_row0_col18 {
#   background-color: #243f99;
#   color: #f1f1f1;
# }
# #T_302e9_row1_col0 {
#   background-color: #55bec1;
#   color: #000000;
# }
# #T_302e9_row1_col1 {
#   background-color: #d4eeb3;
#   color: #000000;
# }
# #T_302e9_row1_col2, #T_302e9_row1_col3, #T_302e9_row7_col16 {
#   background-color: #edf8b2;
#   color: #000000;
# }
# #T_302e9_row1_col4, #T_302e9_row4_col16, #T_302e9_row6_col15 {
#   background-color: #31a5c2;
#   color: #f1f1f1;
# }
# #T_302e9_row1_col5 {
#   background-color: #225aa6;
#   color: #f1f1f1;
# }
# #T_302e9_row1_col7 {
#   background-color: #edf8b1;
#   color: #000000;
# }
# #T_302e9_row1_col8, #T_302e9_row5_col2, #T_302e9_row5_col3, #T_302e9_row5_col7 {
#   background-color: #fdfed4;
#   color: #000000;
# }
# #T_302e9_row1_col9 {
#   background-color: #152772;
#   color: #f1f1f1;
# }
# #T_302e9_row1_col10 {
#   background-color: #bbe4b5;
#   color: #000000;
# }
# #T_302e9_row1_col11 {
#   background-color: #b9e4b5;
#   color: #000000;
# }
# #T_302e9_row1_col12, #T_302e9_row8_col10, #T_302e9_row9_col1 {
#   background-color: #80cebb;
#   color: #000000;
# }
# #T_302e9_row1_col13, #T_302e9_row8_col7, #T_302e9_row8_col11 {
#   background-color: #7ecdbb;
#   color: #000000;
# }
# #T_302e9_row1_col14, #T_302e9_row1_col15 {
#   background-color: #34a9c3;
#   color: #f1f1f1;
# }
# #T_302e9_row1_col16, #T_302e9_row7_col11, #T_302e9_row7_col14 {
#   background-color: #9ed9b8;
#   color: #000000;
# }
# #T_302e9_row1_col17, #T_302e9_row1_col18, #T_302e9_row6_col18 {
#   background-color: #2163aa;
#   color: #f1f1f1;
# }
# #T_302e9_row1_col19 {
#   background-color: #35aac3;
#   color: #f1f1f1;
# }
# #T_302e9_row2_col0 {
#   background-color: #1f7eb7;
#   color: #f1f1f1;
# }
# #T_302e9_row2_col2, #T_302e9_row2_col3 {
#   background-color: #ddf2b2;
#   color: #000000;
# }
# #T_302e9_row2_col5 {
#   background-color: #1e88bc;
#   color: #f1f1f1;
# }
# #T_302e9_row2_col7 {
#   background-color: #dcf1b2;
#   color: #000000;
# }
# #T_302e9_row2_col8 {
#   background-color: #2165ab;
#   color: #f1f1f1;
# }
# #T_302e9_row3_col0, #T_302e9_row3_col1, #T_302e9_row7_col17, #T_302e9_row7_col18 {
#   background-color: #5fc1c0;
#   color: #000000;
# }
# #T_302e9_row3_col2, #T_302e9_row3_col3, #T_302e9_row3_col5, #T_302e9_row3_col7, #T_302e9_row3_col8, #T_302e9_row5_col0, #T_302e9_row5_col1, #T_302e9_row5_col6, #T_302e9_row5_col10, #T_302e9_row5_col11, #T_302e9_row5_col12, #T_302e9_row5_col13, #T_302e9_row5_col14, #T_302e9_row5_col15, #T_302e9_row5_col16, #T_302e9_row5_col17, #T_302e9_row5_col18, #T_302e9_row5_col19, #T_302e9_row7_col4, #T_302e9_row9_col9 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_302e9_row3_col4, #T_302e9_row7_col1 {
#   background-color: #fbfdd0;
#   color: #000000;
# }
# #T_302e9_row3_col9 {
#   background-color: #0a1e5c;
#   color: #f1f1f1;
# }
# #T_302e9_row3_col10, #T_302e9_row7_col0 {
#   background-color: #2498c1;
#   color: #f1f1f1;
# }
# #T_302e9_row3_col11 {
#   background-color: #2296c1;
#   color: #f1f1f1;
# }
# #T_302e9_row3_col12 {
#   background-color: #1f7bb6;
#   color: #f1f1f1;
# }
# #T_302e9_row3_col13, #T_302e9_row4_col10 {
#   background-color: #1f7ab5;
#   color: #f1f1f1;
# }
# #T_302e9_row3_col14, #T_302e9_row3_col15, #T_302e9_row6_col11 {
#   background-color: #1f7db6;
#   color: #f1f1f1;
# }
# #T_302e9_row3_col16 {
#   background-color: #4ab9c3;
#   color: #f1f1f1;
# }
# #T_302e9_row3_col17, #T_302e9_row3_col18, #T_302e9_row8_col19 {
#   background-color: #253b97;
#   color: #f1f1f1;
# }
# #T_302e9_row3_col19, #T_302e9_row6_col10 {
#   background-color: #1f80b8;
#   color: #f1f1f1;
# }
# #T_302e9_row4_col0 {
#   background-color: #1d2e83;
#   color: #f1f1f1;
# }
# #T_302e9_row4_col1, #T_302e9_row5_col8 {
#   background-color: #7cccbb;
#   color: #000000;
# }
# #T_302e9_row4_col4 {
#   background-color: #0c2060;
#   color: #f1f1f1;
# }
# #T_302e9_row4_col6 {
#   background-color: #2094c0;
#   color: #f1f1f1;
# }
# #T_302e9_row4_col8 {
#   background-color: #1a2b7e;
#   color: #f1f1f1;
# }
# #T_302e9_row4_col11 {
#   background-color: #2076b3;
#   color: #f1f1f1;
# }
# #T_302e9_row4_col12 {
#   background-color: #24489d;
#   color: #f1f1f1;
# }
# #T_302e9_row4_col13 {
#   background-color: #24479d;
#   color: #f1f1f1;
# }
# #T_302e9_row4_col14, #T_302e9_row4_col15, #T_302e9_row5_col5 {
#   background-color: #216daf;
#   color: #f1f1f1;
# }
# #T_302e9_row4_col17, #T_302e9_row4_col18 {
#   background-color: #182a7a;
#   color: #f1f1f1;
# }
# #T_302e9_row4_col19 {
#   background-color: #24449c;
#   color: #f1f1f1;
# }
# #T_302e9_row5_col4 {
#   background-color: #87d0ba;
#   color: #000000;
# }
# #T_302e9_row5_col9 {
#   background-color: #0d2163;
#   color: #f1f1f1;
# }
# #T_302e9_row6_col0 {
#   background-color: #234da0;
#   color: #f1f1f1;
# }
# #T_302e9_row6_col1 {
#   background-color: #cdebb4;
#   color: #000000;
# }
# #T_302e9_row6_col2, #T_302e9_row6_col3 {
#   background-color: #3db2c4;
#   color: #f1f1f1;
# }
# #T_302e9_row6_col4 {
#   background-color: #0d2161;
#   color: #f1f1f1;
# }
# #T_302e9_row6_col6 {
#   background-color: #69c5be;
#   color: #000000;
# }
# #T_302e9_row6_col7, #T_302e9_row8_col1 {
#   background-color: #3bb0c3;
#   color: #f1f1f1;
# }
# #T_302e9_row6_col12 {
#   background-color: #2352a3;
#   color: #f1f1f1;
# }
# #T_302e9_row6_col13 {
#   background-color: #2351a2;
#   color: #f1f1f1;
# }
# #T_302e9_row6_col14 {
#   background-color: #2fa4c2;
#   color: #f1f1f1;
# }
# #T_302e9_row6_col16 {
#   background-color: #9cd8b8;
#   color: #000000;
# }
# #T_302e9_row6_col17 {
#   background-color: #2262aa;
#   color: #f1f1f1;
# }
# #T_302e9_row6_col19 {
#   background-color: #3aaec3;
#   color: #f1f1f1;
# }
# #T_302e9_row7_col2, #T_302e9_row7_col3, #T_302e9_row7_col7 {
#   background-color: #f7fcc7;
#   color: #000000;
# }
# #T_302e9_row7_col5 {
#   background-color: #2075b3;
#   color: #f1f1f1;
# }
# #T_302e9_row7_col6 {
#   background-color: #eff9b6;
#   color: #000000;
# }
# #T_302e9_row7_col9 {
#   background-color: #0e2265;
#   color: #f1f1f1;
# }
# #T_302e9_row7_col10, #T_302e9_row7_col15 {
#   background-color: #a0dab8;
#   color: #000000;
# }
# #T_302e9_row7_col12, #T_302e9_row7_col13 {
#   background-color: #8cd2ba;
#   color: #000000;
# }
# #T_302e9_row7_col19 {
#   background-color: #ceecb3;
#   color: #000000;
# }
# #T_302e9_row8_col0 {
#   background-color: #233390;
#   color: #f1f1f1;
# }
# #T_302e9_row8_col2, #T_302e9_row8_col3 {
#   background-color: #83cebb;
#   color: #000000;
# }
# #T_302e9_row8_col4, #T_302e9_row8_col6 {
#   background-color: #24419a;
#   color: #f1f1f1;
# }
# #T_302e9_row8_col5 {
#   background-color: #1e2e85;
#   color: #f1f1f1;
# }
# #T_302e9_row8_col8, #T_302e9_row9_col13 {
#   background-color: #71c8bd;
#   color: #000000;
# }
# #T_302e9_row8_col12 {
#   background-color: #44b7c4;
#   color: #f1f1f1;
# }
# #T_302e9_row8_col13 {
#   background-color: #42b6c4;
#   color: #f1f1f1;
# }
# #T_302e9_row8_col14, #T_302e9_row8_col15 {
#   background-color: #1d8ebf;
#   color: #f1f1f1;
# }
# #T_302e9_row8_col16 {
#   background-col

# %% [markdown]
# ## Post Cruise Processing with additional meta information

# %%
###############################################################
# edit to point to {cruise sepcific} raw datafiles 
datafile = sample_data_dir+'rawconverted/' #<- point to cruise and process all files within
cruise_name = 'DY2209' #no hyphens
cruise_meta_file = sample_data_dir+'logs/DY2209.yaml'
inst_meta_file = sample_data_dir+'logs/FOCI_standard_CTDplusrinko.yaml'
group_meta_file = ecofocipy_dir+'staticdata/institutional_meta_example_ctd.yaml'
inst_shortname = '' #keep as placeholder for now
###############################################################

#init and load data
cruise = sbe_ctd_parser.sbe9_11p()
filename_list = sorted(glob.glob(datafile + '*.cnv'))

(cruise_data,cruise_header) = cruise.parse(filename_list)

# %% [markdown]
# ## Time Properties
#
# Not traditionally dealt with for CTD files as they are likely dynamically updated via GPS feed.  However, FOCI tends to label the date/time with the ***at depth*** time-stamp
#
# ## Depth Properties and other assumptions
#
# - currently, all processing and binning (1m for FOCI) is done via seabird routines and the windows software.  This may change with the python ctd package for a few tasks

# %% [markdown]
# ## Load all external meta information

# %%
#cruise info
with open(cruise_meta_file) as file:
    cruise_config = yaml.full_load(file)

#instrument info
with open(inst_meta_file) as file:
    inst_config = yaml.full_load(file)

#institutional info
with open(group_meta_file) as file:
    group_config = yaml.full_load(file)

# %%
inst_config
# Out:
# {'time': {'epic_key': 'TIM_601',
#   'name': 'time',
#   'generic_name': 'time',
#   'standard_name': 'time',
#   'long_name': 'date and time since reference time',
#   'time_origin': '1900-01-01 00:00:00',
#   'units': 'days since 1900-01-01T00:00:00Z'},
#  'depth': {'epic_key': 'D_3',
#   'generic_name': 'depth',
#   'units': 'meter',
#   'long_name': 'depth below surface (meters)',
#   'standard_name': 'depth'},
#  'latitude': {'epic_key': 'LON_501',
#   'name': 'latitude',
#   'generic_name': 'latitude',
#   'units': 'degrees_north',
#   'long_name': 'latitude',
#   'standard_name': 'latitude'},
#  'longitude': {'epic_key': 'LAT_500',
#   'name': 'longitude',
#   'generic_name': 'longitude',
#   'units': 'degrees_east',
#   'long_name': 'longitude',
#   'standard_name': 'longitude'},
#  'temperature_ch1': {'epic_key': 'T_28',
#   'generic_name': 'temp channel 1',
#   'long_name': 'Sea temperature in-situ ITS-90 scale',
#   'standard_name': 'sea_water_temperature',
#   'units': 'degree_C'},
#  'temperature_ch2': {'epic_key': 'T2_35',
#   'generic_name': 'temp channel 2',
#   'long_name': 'Sea temperature in-situ ITS-90 scale',
#   'standard_name': 'sea_water_temperature',
#   'units': 'degree_C'},
#  'pressure': {'epic_key': 'P_1',
#   'generic_name': 'pres',
#   'units': 'decibar',
#   'long_name': 'Sea water pressure, equals 0 at sea-level',
#   'standard_name': 'sea_water_pressure_due_to_sea_water'},
#  'salinity_ch1': {'epic_key': 'S_41',
#   'generic_name': 'psal channel 1',
#   'units': 'PSU',
#   'long_name': 'Practical salinity in-situ PSS-78 scale',
#   'standard_name': 'sea_water_practical_salinity'},
#  'salinity_ch2': {'epic_key': 'S_42',
#   'generic_name': 'psal channel 2',
#   'units': 'PSU',
#   'long_name': 'Practical salinity in-situ PSS-78 scale',
#   'standard_name': 'sea_water_practical_salinity'},
#  'chlor_fluorescence': {'epic_key': 'F_903',
#   'generic_name': 'chlor_fluorescence',
#   'long_name': 'Mass Concdentration of chlorophyll from chlorophyll fluorescence',
#   'standard_name': 'mass_concentration_of_chlorophyll_in_sea_water',
#   'units': 'ugrams/l'},
#  'turbidity': {'epic_key': 'Trb_980',
#   'generic_name': 'Turbidity',
#   'long_name': 'Turbidity of ocean water in Nephlometric Turbidity Units',
#   'standard_name': 'sea_water_turbidity',
#   'units': 'NTU'},
#  'par': {'generic_name': 'par',
#   'epic_key': 'PAR_905',
#   'long_name': 'Photosynthetic Active Radiation',
#   'standard_name': 'omnidirectional_photosynthetic_photon_spherical_irradiance_in_sea_water',
#   'units': 'uEin cm-2 s-1'},
#  'oxy_conc_ch1': {'generic_name': 'oxy_conc channel 1',
#   'epic_key': 'O_65',
#   'long_name': 'concentration of oxygen in seawater',
#   'standard_name': 'mole_concentration_of_dissolved_molecular_oxygen_in_sea_water',
#   'units': 'micromole/kg'},
#  'oxy_conc_ch2': {'generic_name': 'oxy_conc channel 2',
#   'epic_key': 'CTDOXY_4221',
#   'long_name': 'concentration of oxygen in seawater',
#   'standard_name': 'mole_concentration_of_dissolved_molecular_oxygen_in_sea_water',
#   'units': 'micromole/kg'},
#  'oxy_concM_ch1': {'generic_name': 'oxy_concM channel 1',
#   'epic_key': 'O_65',
#   'long_name': 'concentration of oxygen in seawater',
#   'standard_name': 'mole_concentration_of_dissolved_molecular_oxygen_in_sea_water',
#   'units': 'ml/l'},
#  'oxy_concM_ch2': {'generic_name': 'oxy_concM channel 2',
#   'epic_key': 'O_2060',
#   'long_name': 'concentration of oxygen in seawater',
#   'standard_name': 'mole_concentration_of_dissolved_molecular_oxygen_in_sea_water',
#   'units': 'ml/l'},
#  'oxy_percentsat_ch1': {'generic_name': 'oxy_psat channel 1',
#   'epic_key': 'OST_62',
#   'units': 'percent',
#   'long_name': 'Percent Saturation of oxygen over air',
#   'standard_name': 'fractional_saturation_of_oxygen_in_sea_water'},
#  'oxy_percentsat_ch2': {'generic_name': 'oxy_psat channel 2',
#   'epic_key': 'CTDOST_4220',
#   'units': 'percent',
#   'long_name': 'Percent Saturation of oxygen over air',
#   'standard_name': 'fractional_saturation_of_oxygen_in_sea_water'},
#  'sigma_t_ch1': {'generic_name': 'sigma t channel 1',
#   'epic_key': 'ST_70',
#   'units': 'kg m-3',
#   'long_name': 'sigmat of sea water',
#   'standard_name': 'sea_water_sigma_t'},
#  'sigma_t_ch2': {'generic_name': 'sigma t channel 2',
#   'epic_key': 'ST_2070',
#   'units': 'kg m-3',
#   'long_name': 'sigmat of sea water',
#   'standard_name': 'sea_water_sigma_t'},
#  'temperature_rinko': {'epic_key': '',
#   'generic_name': 'Rinko Temperature',
#   'long_name': 'Sea temperature in-situ ITS-90 scale',
#   'standard_name': 'sea_water_temperature',
#   'units': 'degree_C'},
#  'voltage_rinko': {'epic_key': '',
#   'generic_name': 'Rinko Voltage',
#   'long_name': 'Rinko Oxygen Optode Voltage',
#   'standard_name': 'voltage',
#   'units': 'V'}}

# %%
cruise_config['CTDCasts']['CTD001']
# Out:
# {'id': 53912,
#  'Vessel': 'NOAAS Oscar Dyson',
#  'CruiseID': 'DY2209',
#  'Project_Leg': '',
#  'UniqueCruiseID': 'DY2209',
#  'Project': 'FOCI Fall Cruise',
#  'StationNo_altname': '1',
#  'ConsecutiveCastNo': 'CTD001',
#  'LatitudeDeg': 64,
#  'LatitudeMin': 0.23,
#  'LongitudeDeg': 163,
#  'LongitudeMin': 3.97,
#  'GMTDay': 21,
#  'GMTMonth': 'Sep',
#  'GMTYear': 2022,
#  'GMTTime': 18600,
#  'DryBulb': 4.9,
#  'RelativeHumidity': 92,
#  'WetBulb': -99.9,
#  'Pressure': 1012,
#  'SeaState': '',
#  'Visibility': '',
#  'WindDir': 213,
#  'WindSpd': 12.8,
#  'CloudAmt': '',
#  'CloudType': '',
#  'Weather': '',
#  'SurfaceTemp': 6.75,
#  'BottomDepth': 38,
#  'StationNameID': 'M14',
#  'MaxDepth': 33,
#  'InstrumentSerialNos': '',
#  'Notes': '',
#  'NutrientBtlNiskinNo': '1;2;3;;5;6',
#  'NutrientBtlNumbers': '1;2;3;;4',
#  'OxygenBtlNiskinNo': '1;1;2;3;;5',
#  'OxygenBtlNumbers': '227;239;241;242;;243',
#  'SalinityBtlNiskinNo': '1',
#  'SalinityBtlNumbers': '632',
#  'ChlorophyllBtlNiskinNo': '1;2;3;;5',
#  'ChlorophyllBtlVolumes': '285;281;283;;283',
#  'InstrumentType': 'SBE911plus',
#  'WaterMassCode': 'B',
#  'isMooringProfileCast': 'n',
#  'MooringID': '',
#  'QualityControlled': 'n',
#  'FileName': ''}

# %%
for cast in cruise_data.keys():
    print(f'Processing Cast {cast}')

    try:
        #output cruise cast stats here
        #cruise_data[cast].describe()
        #cruise_data['ctd001.cnv'].hist() - seaborn may have a better summary plot than just a bunch of histograms
        #sns.pairplot(cruise_data[cast])
        lower_columns = [x.lower() for x in cruise_data[cast].columns]
        # cruise_data[cast].columns = lower_columns
        cruise_data[cast] = cruise_data[cast].rename(columns={
                            't090C':'temperature_ch1',
                            't190C':'temperature_ch2',
                            'sal00':'salinity_ch1',
                            'sal11':'salinity_ch2',
                            'sbox0Mm/Kg':'oxy_conc_ch1',
                            'sbeox0ML/L':'oxy_concM_ch1',
                            'sbeox0PS':'oxy_percentsat_ch1',
                            'sbox1Mm/Kg':'oxy_conc_ch2',
                            'sbeox1ML/L':'oxy_concM_ch2',
                            'sbeox1PS':'oxy_percentsat_ch2',
                            'sigma-t00':'sigma_t_ch1',
                            'sigma-t11':'sigma_t_ch2',
                            'flECO-AFL':'chlor_fluorescence',
                            'turbWETntu0':'turbidity',
                            'cstarat0':'Attenuation',
                            'cstartr0':'Transmittance',
                            'upoly0':'temperature_rinko',
                            'v6':'voltage_rinko',
                            'par':'par',
                            'empty':'empty', #this will be ignored
                            'flag':'flag'})

        cruise_data[cast].index.rename('depth',inplace=True)
        #cruise_data[cast].sample()

        cruise_data_nc = ncCFsave.EcoFOCI_CFnc(df=cruise_data[cast], 
                                instrument_yaml=inst_config, 
                                operation_yaml=cruise_config,
                                operation_type='ctd')
        cruise_data_nc.expand_dimensions(dim_names=['latitude','longitude','time'],geophys_sort=False)
        cruise_data_nc.variable_meta_data(variable_keys=list(cruise_data[cast].columns.values),drop_missing=True)
        cruise_data_nc.dimension_meta_data(variable_keys=['depth','latitude','longitude'])
        cruise_data_nc.temporal_geospatioal_meta_data_ctd(positiveE=False,conscastno=cast.split('.')[0])

        cruise_data_nc.var_qcflag_init(dim_names=['depth','latitude','longitude','time'])

        #interp to sfc for list of vars
        cruise_data_nc.interp2sfc(novars=['par'])

        #add global attributes
        cruise_data_nc.deployment_meta_add(conscastno=cast.upper().split('.')[0])
        cruise_data_nc.get_xdf()

        #add instituitonal global attributes
        cruise_data_nc.institution_meta_add(group_config)

        #add creation date/time - provenance data
        cruise_data_nc.provinance_meta_add()

        #provide intial qc status field
        cruise_data_nc.qc_status(qc_status='unknown')

        cast_label = cast.split('.')[0].split('d')[-1]
        cruise_data_nc.xarray2netcdf_save(xdf = cruise_data_nc.get_xdf(),
                                filename=sample_data_dir+cruise_name+'c'+cast_label.zfill(3)+'_ctd.nc',format="NETCDF3_CLASSIC")
        #generate editable csv files
        to_edit = True
        if to_edit:
            if not cast[0] in ['d','u']: #dont save editable up and downcast files, just nc files for plotting... all u/d files can be removed after final data
                cruise_data_nc.get_xdf().to_dataframe().to_csv(sample_data_dir+cruise_name+'c'+cast_label.zfill(3)+'_ctd.to_edit.csv')  

    except:
       print('Conversion Failed')
# Out:
# Processing Cast CTD001.cnv
# Processing Cast CTD002.cnv
# Processing Cast CTD003.cnv
# Processing Cast CTD004.cnv
# Processing Cast CTD005.cnv
# Processing Cast dCTD001.cnv
# Conversion Failed
# Processing Cast dCTD002.cnv
# Conversion Failed
# Processing Cast dCTD003.cnv
# Conversion Failed
# Processing Cast dCTD004.cnv
# Conversion Failed
# Processing Cast dCTD005.cnv
# Conversion Failed
# Processing Cast uCTD001.cnv
# Conversion Failed
# Processing Cast uCTD002.cnv
# Conversion Failed
# Processing Cast uCTD003.cnv
# Conversion Failed
# Processing Cast uCTD004.cnv
# Conversion Failed
# Processing Cast uCTD005.cnv
# Conversion Failed

# %% [markdown]
# ## QC Next Steps

# %%
import ecofocipy.plots.sbe_ctd_plots as sbe_ctd_plots
import os
import xarray as xa
import seaborn as sns
import numpy as np

# %%
sample_data_dir = '/Users/bell/ecoraid/2022/CTDcasts/dy2209/final_data_cf/ctd/' #root path to cruise directory working repo

# %% [markdown]
# ### QC of data (plot parameters with other instruments)
# - be sure to updated the qc_status for the file and the history for future steps
# - from NRT csv files... make edits then use that to modify netcdf?
# - **Better Yet** export netcdf files with variable flags to csv and edit then reingest and modify
#     - modify netcdf in place and provide a qcflag?
#
#
# ### Likely first edits
# - research issues noted in cruise logs
# - remove failed instrument (clogs, or other challenges that arent correctable)
# - extrapolate to sfc (not par though)
# - despike depths (interpolate between depths)
# - check for common issues
#     - lags in salinity when going through interface

# %%
#test for salinity bottle run needs
for cast in sorted(os.listdir(sample_data_dir)):
    if cast.endswith('.nc'):
        cruise_data_nc = xa.load_dataset(sample_data_dir+cast)
        saldiff = cruise_data_nc.salinity_ch1 - cruise_data_nc.salinity_ch2
        print(f"Profile Averaged Salinity {cast} Difference,STD (chan1-chan2){saldiff.mean().values},{saldiff.std().values}")        
        saldiff.plot.hist(bins=50,xlim=[-.005,.005])
# Out:
# Profile Averaged Salinity DY2209cCTD001_ctd.nc Difference,STD (chan1-chan2)0.0015628571428568502,0.0007131762812678587
# Profile Averaged Salinity DY2209cCTD002_ctd.nc Difference,STD (chan1-chan2)0.00013999999999977523,0.006576373294931781
# Profile Averaged Salinity DY2209cCTD003_ctd.nc Difference,STD (chan1-chan2)0.004172093023255922,0.004524780636152688
# Profile Averaged Salinity DY2209cCTD004_ctd.nc Difference,STD (chan1-chan2)0.0021195652173913847,0.0038095200864711664
# Profile Averaged Salinity DY2209cCTD005_ctd.nc Difference,STD (chan1-chan2)0.0013720930232556732,0.0009993778486485946

# %% [markdown]
# ## Generate Plots
#
#
# ### Make General Plots
# - 1:1 plots for paired instruments for each cast (tells if a sensor failed)
# - TS_Sigmat, Chlor/Par/Turb, Oxy,Temp
# - T/S property property plot
# - upcast/downcast plt

# %% [markdown]
# ### Look at max par values as hour of day - this cruise may have an issue with sensor

# %%
from matplotlib import pyplot as plt
import os

fig = plt.figure()

for cast in sorted(os.listdir(sample_data_dir)):
    if cast.endswith('.nc'):
        cruise_data_nc = xa.load_dataset(sample_data_dir+cast)
        plt.plot(cruise_data_nc.time.dt.hour,cruise_data_nc['par'].max(),'r.')

# %%
import seawater as sw

def sigmat_update(salinity=None,temperature=None):
    '''
    Changes to T or S (commonly to despike values or apply a salinity offset) will need corresponding changes in sigmat
    '''
    # calculate sigmaT at 0db gauge pressure (s, t, p=0)
    sigt = (sw.eos80.dens0(s=salinity, t=temperature) - 1000)
    
    return sigt

# %%
for cast in sorted(os.listdir(sample_data_dir)):
    if cast.endswith('.nc'):
        cruise_data_nc = xa.load_dataset(sample_data_dir+cast)
        ctd_df = cruise_data_nc.to_dataframe()
        

                #update sigmat (or calculate it I suppose)
        sigup = sigmat_update(salinity=ctd_df.salinity_ch1,
                              temperature=ctd_df.temperature_ch1)
        sigup2 = sigmat_update(salinity=ctd_df.salinity_ch2,
                              temperature=ctd_df.temperature_ch2)
        
        sbe_p = sbe_ctd_plots.CTDProfilePlot()
        plt,fig =sbe_p.plot3var(varname=['temperature_ch1','temperature_ch2','salinity_ch1','salinity_ch2','sigma_t_ch1','sigma_t_ch2'],
                          xdata=[ctd_df.temperature_ch1,ctd_df.temperature_ch2,ctd_df.salinity_ch1,ctd_df.salinity_ch2,sigup,sigup2],
                          ydata=ctd_df.index.get_level_values('depth'),
                          secondary=True,
                          xlabel=['Temperature','Salinity','Sigma-T'])

        DefaultSize = fig.get_size_inches()
        fig.set_size_inches( (DefaultSize[0], DefaultSize[1]*3) )
        plt.savefig(sample_data_dir+cast.replace('.nc','_TempSalSigmat.png'))
        plt.close(fig)

# %%
for cast in sorted(os.listdir(sample_data_dir)):
    if cast.endswith('.nc'):
        cruise_data_nc = xa.load_dataset(sample_data_dir+cast)
        ctd_df = cruise_data_nc.to_dataframe()
        
        sbe_p = sbe_ctd_plots.CTDProfilePlot()
        plt,fig =sbe_p.plot2var(varname=['temperature_ch1','temperature_ch2','oxy_percentsat_ch1','oxy_percentsat_ch2'],
                          xdata=[ctd_df.temperature_ch1,ctd_df.temperature_ch2,ctd_df.oxy_percentsat_ch1,ctd_df.oxy_percentsat_ch2],
                          ydata=ctd_df.index.get_level_values('depth'),
                          secondary=True,
                          xlabel=['Temperature','Oxygen Saturation'])

        DefaultSize = fig.get_size_inches()
        fig.set_size_inches( (DefaultSize[0], DefaultSize[1]*3) )
        plt.savefig(sample_data_dir+cast.replace('.nc','_TempOxy.png'))
        plt.close(fig)

# %%
for cast in sorted(os.listdir(sample_data_dir)):
    if cast.endswith('.nc'):
        cruise_data_nc = xa.load_dataset(sample_data_dir+cast)
        ctd_df = cruise_data_nc.to_dataframe()
        
        sbe_p = sbe_ctd_plots.CTDProfilePlot()
        plt,fig =sbe_p.plot3var(varname=['turbidity','','chlor_fluorescence','','par',''],
                          xdata=[ctd_df.turbidity,np.array([]),ctd_df.chlor_fluorescence,np.array([]),ctd_df.par,np.array([])],
                          ydata=ctd_df.index.get_level_values('depth'),
                          secondary=True,
                          xlabel=['Turbidity','Fluor','Par'])

        DefaultSize = fig.get_size_inches()
        fig.set_size_inches( (DefaultSize[0], DefaultSize[1]*3) )
        plt.savefig(sample_data_dir+cast.replace('.nc','_TurbFluorPar.png'))
        plt.close(fig)

# %%
#cruise_data_nc.get_xdf().to_dataframe().columns
sns.pairplot(cruise_data_nc.to_dataframe()[['salinity_ch1', 'salinity_ch2',]])
