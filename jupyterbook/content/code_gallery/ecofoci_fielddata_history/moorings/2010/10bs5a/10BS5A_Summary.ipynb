# %% [markdown]
# # Mooring Synthesis of Initial NC data (offline)
#
# ## 10BS-5A
#
# - from netcdf files
# - plot all depths of each parameter on each other for comparative purposes
# - Temperature, Salinity, Pressure in this notebook.  See companion for Oxygen, Chlor, ADCP/currents, etc

# %%
import xarray as xa
import pandas as pd
import numpy as np
import cmocean

# %%
#wrap the plot in image settings for visual appeal
# may be able to make this cleaner or just a preset
# %run '../../../settings/mpl_plot_settings.py'

# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.dates import YearLocator, WeekdayLocator, MonthLocator, DayLocator, HourLocator, DateFormatter
import matplotlib.ticker as ticker

# %%
# ncfiles = '/Users/bell/ecoraid/2022/Moorings/22bs2c/final_data_cf/22bs*.nc'
ncfiles = '*.nc'
mfd = xa.open_mfdataset(ncfiles)
mfd
# Out:
# <xarray.Dataset>
# Dimensions:             (time: 2009, depth: 2, latitude: 1, longitude: 1)
# Coordinates:
#   * time                (time) datetime64[ns] 2010-07-04T08:00:00 ... 2010-09-26
#   * latitude            (latitude) float64 59.91
#   * longitude           (longitude) float64 -171.7
#   * depth               (depth) float64 11.5 24.0
# Data variables:
#     chlor_fluorescence  (time, depth, latitude, longitude) float64 dask.array<chunksize=(2009, 1, 1, 1), meta=np.ndarray>
# Attributes: (12/15)
#     Latitude_DegMMddW:                      59 54.81 N
#     Longitude_DegMMddN:                     171 41.562 W
#     MooringID:                              10BS-5A
#     platform_deployment_date:               2010-07-04T07:49:00Z
#     platform_deployment_cruise_name:        DY1006
#     platform_recovery_date:                 2010-09-26T00:00:00Z
#     ...                                     ...
#     InstrumentSerialNumber:                 158
#     InstrumentType:                         Eco-Fluorometer FLSB
#     date_created:                           2024-02-21T14:38:46Z
#     date_modified:
#     QC_indicator:                           unknown
#     history:                                Trimmed to deployment.\nTrimmed t...

# %% [markdown]
# ## Temperature (full temporal resolution)

# %%
upper_temp = mfd.temperature.max(axis=0).max(axis=0).values
lower_temp = -2

fig, ax = plt.subplots(1,figsize=(24, 2))
mfd.temperature.T.plot(ax=ax,yincrease=False,vmin=lower_temp,vmax=upper_temp,cmap=cmocean.cm.thermal)


ax.xaxis.set_major_locator(DayLocator(bymonthday=1))
ax.xaxis.set_minor_locator(DayLocator(bymonthday=15))
ax.xaxis.set_minor_formatter(DateFormatter('%b %Y'))
ax.xaxis.set_major_formatter(DateFormatter(''))
ax.xaxis.set_tick_params(which='major', pad=3)
ax.xaxis.set_tick_params(which='minor', pad=5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 upper_temp = mfd.temperature.max(axis=0).max(axis=0).values
#       2 lower_temp = -2
#       4 fig, ax = plt.subplots(1,figsize=(24, 2))
#
# File ~/mambaforge/envs/py310/lib/python3.10/site-packages/xarray/core/common.py:277, in AttrAccessMixin.__getattr__(self, name)
#     275         with suppress(KeyError):
#     276             return source[name]
# --> 277 raise AttributeError(
#     278     f"{type(self).__name__!r} object has no attribute {name!r}"
#     279 )
#
# AttributeError: 'Dataset' object has no attribute 'temperature'

# %%
fig, ax = plt.subplots(1,figsize=(24, 2))
mfd.isel(latitude=0,longitude=0).plot.scatter(x="time",y="temperature",hue="depth",s=1,ax=ax)


ax.xaxis.set_major_locator(DayLocator(bymonthday=1))
ax.xaxis.set_minor_locator(DayLocator(bymonthday=15))
ax.xaxis.set_minor_formatter(DateFormatter('%b %Y'))
ax.xaxis.set_major_formatter(DateFormatter(''))
ax.xaxis.set_tick_params(which='major', pad=3)
ax.xaxis.set_tick_params(which='minor', pad=5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/mambaforge/envs/py310/lib/python3.10/site-packages/xarray/core/dataset.py in ?(self, name)
#    1426             variable = self._variables[name]
#    1427         except KeyError:
# -> 1428             _, name, variable = _get_virtual_variable(self._variables, name, self.dims)
#    1429
#
# KeyError: 'temperature'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/g1/6qjvrwsx0vb6ltz_4gv0tmxr0000jm/T/ipykernel_95604/2514081582.py in ?()
#       1 fig, ax = plt.subplots(1,figsize=(24, 2))
# ----> 2 mfd.isel(latitude=0,longitude=0).plot.scatter(x="time",y="temperature",hue="depth",s=1,ax=ax)
#       3
#       4
#       5 ax.xaxis.set_major_locator(DayLocator(bymonthday=1))
#
# ~/mambaforge/envs/py310/lib/python3.10/site-packages/xarray/plot/accessor.py in ?(self, *args, **kwargs)
#    1070     @functools.wraps(dataset_plot.scatter)
#    1071     def scatter(self, *args, **kwargs) -> PathCollection | FacetGrid[DataArray]:
# -> 1072         return dataset_plot.scatter(self._ds, *args, **kwargs)
#
# ~/mambaforge/envs/py310/lib/python3.10/site-packages/xarray/plot/dataset_plot.py in ?(ds, x, y, z, hue, hue_style, markersize, linewidth, figsize, size, aspect, ax, row, col, col_wrap, xincrease, yincrease, add_legend, add_colorbar, add_labels, add_title, subplot_kws, xscale, yscale, xticks, yticks, xlim, ylim, cmap, vmin, vmax, norm, extend, levels, *args, **kwargs)
#     915     """Scatter plot Dataset data variables against each other."""
#     916     locals_ = locals()
#     917     del locals_["ds"]
#     918     locals_.update(locals_.pop("kwargs", {}))
# --> 919     da = _temp_dataarray(ds, y, locals_)
#     920
#     921     return da.plot.scatter(*locals_.pop("args", ()), **locals_)
#
# ~/mambaforge/envs/py310/lib/python3.10/site-packages/xarray/plot/dataset_plot.py in ?(ds, y, locals_)
#     741             coords[key] = ds[key]
#     742
#     743     # The dataarray has to include all the dims. Broadcast to that shape
#     744     # and add the additional coords:
# --> 745     _y = ds[y].broadcast_like(ds)
#     746
#     747     return DataArray(_y, coords=coords)
#
# ~/mambaforge/envs/py310/lib/python3.10/site-packages/xarray/core/dataset.py in ?(self, key)
#    1513         """
#    1514         if utils.is_dict_like(key):
#    1515             return self.isel(**key)
#    1516         if utils.hashable(key):
# -> 1517             return self._construct_dataarray(key)
#    1518         if utils.iterable_of_hashable(key):
#    1519             return self._copy_listed(key)
#    1520         raise ValueError(f"Unsupported key-type {type(key)}")
#
# ~/mambaforge/envs/py310/lib/python3.10/site-packages/xarray/core/dataset.py in ?(self, name)
#    1424
#    1425         try:
#    1426             variable = self._variables[name]
#    1427         except KeyError:
# -> 1428             _, name, variable = _get_virtual_variable(self._variables, name, self.dims)
#    1429
#    1430         needed_dims = set(variable.dims)
#    1431
#
# ~/mambaforge/envs/py310/lib/python3.10/site-packages/xarray/core/dataset.py in ?(variables, key, dim_sizes)
#     196         raise KeyError(key)
#     197
#     198     split_key = key.split(".", 1)
#     199     if len(split_key) != 2:
# --> 200         raise KeyError(key)
#     201
#     202     ref_name, var_name = split_key
#     203     ref_var = variables[ref_name]
#
# KeyError: 'temperature'

# %% [markdown]
# **Note:** not everything has constant sample frequencies so if nan's are in the mix, then lineplots are less useful (see plot below)
# Will want to resample to hourly or daily to evaluate those

# %%
import datetime

# %%
fig, ax = plt.subplots(1,figsize=(18, 2))
mfd.temperature.isel(latitude=0,longitude=0).plot.line(x="time",hue="depth",ax=ax);
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 2
#       1 fig, ax = plt.subplots(1,figsize=(18, 2))
# ----> 2 mfd.temperature.isel(latitude=0,longitude=0).plot.line(x="time",hue="depth",ax=ax);
#
# File ~/mambaforge/envs/py310/lib/python3.10/site-packages/xarray/core/common.py:277, in AttrAccessMixin.__getattr__(self, name)
#     275         with suppress(KeyError):
#     276             return source[name]
# --> 277 raise AttributeError(
#     278     f"{type(self).__name__!r} object has no attribute {name!r}"
#     279 )
#
# AttributeError: 'Dataset' object has no attribute 'temperature'

# %% [markdown]
# ## Salinity(full temporal resolution)

# %%
fig, ax = plt.subplots(1,figsize=(16, 2))
mfd.isel(latitude=0,longitude=0).plot.scatter(x="time",y="salinity",hue="depth",s=1,ax=ax)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/mambaforge/envs/py310/lib/python3.10/site-packages/xarray/core/dataset.py in ?(self, name)
#    1426             variable = self._variables[name]
#    1427         except KeyError:
# -> 1428             _, name, variable = _get_virtual_variable(self._variables, name, self.dims)
#    1429
#
# KeyError: 'salinity'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/g1/6qjvrwsx0vb6ltz_4gv0tmxr0000jm/T/ipykernel_95604/1243301279.py in ?()
#       1 fig, ax = plt.subplots(1,figsize=(16, 2))
# ----> 2 mfd.isel(latitude=0,longitude=0).plot.scatter(x="time",y="salinity",hue="depth",s=1,ax=ax)
#
# ~/mambaforge/envs/py310/lib/python3.10/site-packages/xarray/plot/accessor.py in ?(self, *args, **kwargs)
#    1070     @functools.wraps(dataset_plot.scatter)
#    1071     def scatter(self, *args, **kwargs) -> PathCollection | FacetGrid[DataArray]:
# -> 1072         return dataset_plot.scatter(self._ds, *args, **kwargs)
#
# ~/mambaforge/envs/py310/lib/python3.10/site-packages/xarray/plot/dataset_plot.py in ?(ds, x, y, z, hue, hue_style, markersize, linewidth, figsize, size, aspect, ax, row, col, col_wrap, xincrease, yincrease, add_legend, add_colorbar, add_labels, add_title, subplot_kws, xscale, yscale, xticks, yticks, xlim, ylim, cmap, vmin, vmax, norm, extend, levels, *args, **kwargs)
#     915     """Scatter plot Dataset data variables against each other."""
#     916     locals_ = locals()
#     917     del locals_["ds"]
#     918     locals_.update(locals_.pop("kwargs", {}))
# --> 919     da = _temp_dataarray(ds, y, locals_)
#     920
#     921     return da.plot.scatter(*locals_.pop("args", ()), **locals_)
#
# ~/mambaforge/envs/py310/lib/python3.10/site-packages/xarray/plot/dataset_plot.py in ?(ds, y, locals_)
#     741             coords[key] = ds[key]
#     742
#     743     # The dataarray has to include all the dims. Broadcast to that shape
#     744     # and add the additional coords:
# --> 745     _y = ds[y].broadcast_like(ds)
#     746
#     747     return DataArray(_y, coords=coords)
#
# ~/mambaforge/envs/py310/lib/python3.10/site-packages/xarray/core/dataset.py in ?(self, key)
#    1513         """
#    1514         if utils.is_dict_like(key):
#    1515             return self.isel(**key)
#    1516         if utils.hashable(key):
# -> 1517             return self._construct_dataarray(key)
#    1518         if utils.iterable_of_hashable(key):
#    1519             return self._copy_listed(key)
#    1520         raise ValueError(f"Unsupported key-type {type(key)}")
#
# ~/mambaforge/envs/py310/lib/python3.10/site-packages/xarray/core/dataset.py in ?(self, name)
#    1424
#    1425         try:
#    1426             variable = self._variables[name]
#    1427         except KeyError:
# -> 1428             _, name, variable = _get_virtual_variable(self._variables, name, self.dims)
#    1429
#    1430         needed_dims = set(variable.dims)
#    1431
#
# ~/mambaforge/envs/py310/lib/python3.10/site-packages/xarray/core/dataset.py in ?(variables, key, dim_sizes)
#     196         raise KeyError(key)
#     197
#     198     split_key = key.split(".", 1)
#     199     if len(split_key) != 2:
# --> 200         raise KeyError(key)
#     201
#     202     ref_name, var_name = split_key
#     203     ref_var = variables[ref_name]
#
# KeyError: 'salinity'

# %% [markdown]
# ## Pressure (full temporal resolution)

# %%
fig, ax = plt.subplots(1,figsize=(16, 2))
mfd.isel(latitude=0,longitude=0).plot.scatter(x="time",y="pressure",hue="depth",s=1,ax=ax)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/mambaforge/envs/py310/lib/python3.10/site-packages/xarray/core/dataset.py in ?(self, name)
#    1426             variable = self._variables[name]
#    1427         except KeyError:
# -> 1428             _, name, variable = _get_virtual_variable(self._variables, name, self.dims)
#    1429
#
# KeyError: 'pressure'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/g1/6qjvrwsx0vb6ltz_4gv0tmxr0000jm/T/ipykernel_95604/765011484.py in ?()
#       1 fig, ax = plt.subplots(1,figsize=(16, 2))
# ----> 2 mfd.isel(latitude=0,longitude=0).plot.scatter(x="time",y="pressure",hue="depth",s=1,ax=ax)
#
# ~/mambaforge/envs/py310/lib/python3.10/site-packages/xarray/plot/accessor.py in ?(self, *args, **kwargs)
#    1070     @functools.wraps(dataset_plot.scatter)
#    1071     def scatter(self, *args, **kwargs) -> PathCollection | FacetGrid[DataArray]:
# -> 1072         return dataset_plot.scatter(self._ds, *args, **kwargs)
#
# ~/mambaforge/envs/py310/lib/python3.10/site-packages/xarray/plot/dataset_plot.py in ?(ds, x, y, z, hue, hue_style, markersize, linewidth, figsize, size, aspect, ax, row, col, col_wrap, xincrease, yincrease, add_legend, add_colorbar, add_labels, add_title, subplot_kws, xscale, yscale, xticks, yticks, xlim, ylim, cmap, vmin, vmax, norm, extend, levels, *args, **kwargs)
#     915     """Scatter plot Dataset data variables against each other."""
#     916     locals_ = locals()
#     917     del locals_["ds"]
#     918     locals_.update(locals_.pop("kwargs", {}))
# --> 919     da = _temp_dataarray(ds, y, locals_)
#     920
#     921     return da.plot.scatter(*locals_.pop("args", ()), **locals_)
#
# ~/mambaforge/envs/py310/lib/python3.10/site-packages/xarray/plot/dataset_plot.py in ?(ds, y, locals_)
#     741             coords[key] = ds[key]
#     742
#     743     # The dataarray has to include all the dims. Broadcast to that shape
#     744     # and add the additional coords:
# --> 745     _y = ds[y].broadcast_like(ds)
#     746
#     747     return DataArray(_y, coords=coords)
#
# ~/mambaforge/envs/py310/lib/python3.10/site-packages/xarray/core/dataset.py in ?(self, key)
#    1513         """
#    1514         if utils.is_dict_like(key):
#    1515             return self.isel(**key)
#    1516         if utils.hashable(key):
# -> 1517             return self._construct_dataarray(key)
#    1518         if utils.iterable_of_hashable(key):
#    1519             return self._copy_listed(key)
#    1520         raise ValueError(f"Unsupported key-type {type(key)}")
#
# ~/mambaforge/envs/py310/lib/python3.10/site-packages/xarray/core/dataset.py in ?(self, name)
#    1424
#    1425         try:
#    1426             variable = self._variables[name]
#    1427         except KeyError:
# -> 1428             _, name, variable = _get_virtual_variable(self._variables, name, self.dims)
#    1429
#    1430         needed_dims = set(variable.dims)
#    1431
#
# ~/mambaforge/envs/py310/lib/python3.10/site-packages/xarray/core/dataset.py in ?(variables, key, dim_sizes)
#     196         raise KeyError(key)
#     197
#     198     split_key = key.split(".", 1)
#     199     if len(split_key) != 2:
# --> 200         raise KeyError(key)
#     201
#     202     ref_name, var_name = split_key
#     203     ref_var = variables[ref_name]
#
# KeyError: 'pressure'

# %% [markdown]
# ## Hourly/Interpolated plots Plots
#
# Because of the different timebases... quickly either interpolate (linearly) or downsample (this seems slower) to plot all series

# %%
# mfd_hourly = mfd.resample(time='1H').median() #not fast
mfd_up = (mfd.interpolate_na("time")).resample({'time':'1H'}).mean()

# %%
fig, ax = plt.subplots(1,figsize=(16, 2))
mfd_up.temperature.plot(x="time",hue="depth",ax=ax)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 2
#       1 fig, ax = plt.subplots(1,figsize=(16, 2))
# ----> 2 mfd_up.temperature.plot(x="time",hue="depth",ax=ax)
#
# File ~/mambaforge/envs/py310/lib/python3.10/site-packages/xarray/core/common.py:277, in AttrAccessMixin.__getattr__(self, name)
#     275         with suppress(KeyError):
#     276             return source[name]
# --> 277 raise AttributeError(
#     278     f"{type(self).__name__!r} object has no attribute {name!r}"
#     279 )
#
# AttributeError: 'Dataset' object has no attribute 'temperature'

# %%
fig, ax = plt.subplots(1,figsize=(16, 2))
mfd_up.salinity.plot(x="time",hue="depth",ax=ax);

# %%
upper_temp = mfd_up.temperature.max(axis=0).max(axis=0).values
lower_temp = -2

fig, ax = plt.subplots(1,figsize=(16, 2))
mfd_up.temperature.T.plot(ax=ax,yincrease=False,vmin=lower_temp,vmax=14,cmap=cmocean.cm.thermal)

# %% [markdown]
# ## Chlorophyll Hourly Interpolated Plots

# %%
fig, ax = plt.subplots(1,figsize=(16, 2))
mfd_up.chlor_fluorescence.plot(x="time",hue="depth",ax=ax);
(mfd_up.isel({'depth':0}).chlor_fluorescence*0).plot(ax=ax,c='k',add_legend=False); #zeroline

# %%
upper = 25
lower = 0

fig, ax = plt.subplots(1,figsize=(16, 2))
mfd_up.chlor_fluorescence.T.plot(ax=ax,yincrease=False,vmin=lower,vmax=upper,cmap=cmocean.cm.algae)

# %% [markdown]
# ## Compare Timeseries to CTD Casts
#
#
# - Recovery CTDXXX on Sikuliaq cruise, not yet obtained.

# %%
import ecofocipy.io.erddap as erddap

# %%
url = "http://ecofoci-field.pmel.noaa.gov:8082/erddap"

erddap.test_erddap_connection(url=url) #basic test for connection to internal server, no response is a good thing

# %%
#grap deploy/recover cast data from erddap hosted sets - you have to know which profile you want though
# depcast = erddap.erddapCTDretrieve(url=url,cruiseid='dy2206',qclevel='preliminary',concastno='001')
reccast = erddap.erddapCTDretrieve(url=url,cruiseid='dy2306',qclevel='preliminary',concastno='059')

# %% [markdown]
# ## QC Notes
#
#
#
# (PJS needs to vet these)

# %% [markdown]
# ## Generate to_edit files for PJS
#
# - these are usually salinity focused and need the ctd casts as well as the salinity timeseries.
# - save the native time scale, not the interpolated or upscaled version

# %%
with pd.ExcelWriter('22bs2c_salinity_to_edit.xlsx') as writer:  

    for depthkey in mfd.to_dataframe().salinity.groupby(level=[1]).groups.keys():
        if not (mfd.to_dataframe().salinity.groupby(level=[1]).get_group(depthkey).dropna(how='all')).empty:
            print(f'saving {depthkey}')
            (mfd.to_dataframe().salinity.groupby(level=[1]).get_group(depthkey).dropna(axis=0)).to_excel(writer, sheet_name=str(depthkey))

    depcast.to_excel(writer, sheet_name=depcast.profile_id.unique()[0])
    # reccast.to_excel(writer, sheet_name=reccast.profile_id.unique()[0])
# Out:
# saving 56.874266666666664

# %%
with pd.ExcelWriter('22bs2c_fluor.xlsx') as writer:  

    for depthkey in mfd_up.chlor_fluorescence.to_dataframe().droplevel(['latitude','longitude']).groupby(level=['depth']).groups.keys():
        print(depthkey)
        if not (mfd_up.chlor_fluorescence.to_dataframe().droplevel(['latitude','longitude']).groupby(level=['depth']).get_group(depthkey).dropna(how='all')).empty:
            print(f'saving {depthkey}')
            (mfd_up.chlor_fluorescence.to_dataframe().droplevel(['latitude','longitude']).groupby(level=['depth']).get_group(depthkey).dropna(axis=0)).droplevel(['depth']).to_excel(writer, sheet_name=str(depthkey))

    # depcast.to_excel(writer, sheet_name=depcast.profile_id.unique()[0])
    # reccast.to_excel(writer, sheet_name=reccast.profile_id.unique()[0])
