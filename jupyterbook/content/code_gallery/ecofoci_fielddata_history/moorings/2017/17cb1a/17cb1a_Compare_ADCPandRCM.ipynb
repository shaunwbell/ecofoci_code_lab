# %% [markdown]
# # EcoFOCIpy RCM vs ADCP - 17CB-1A
#
# Compare data using the ERDDAP hosted datasets for both instruments:
# - 2D EIN/Vel datasets for the ADCP
# - 1D dataset (at a specific depth) embedded in the mooring dataset

# %%
import pandas as pd
import xarray as xr
import datetime
import ecofocipy.io.erddap as erddap

url = "http://ecofoci-field.pmel.noaa.gov:8080/erddap"

erddap.test_erddap_connection(url=url) #basic test for connection to internal server, no response is a good thing

# %%
rcm_data = erddap.erddapMooredInstretrieve(url=url,mooringid='17cb1a',qclevel='final',instrid='17cb1a_an9_0181m')
rcm_data.columns = [x.split()[0] for x in rcm_data.columns]

# %%
rcm_data = rcm_data.set_index(pd.to_datetime(rcm_data['time'])).tz_localize(None).drop('time',axis=1)

# %%
adcp_data = xr.load_dataset(url+'/griddap/ADCP_Mooring_17cb1a_final')
# Out:
# /Users/bell/miniconda3/envs/py38/lib/python3.8/site-packages/xarray/conventions.py:523: SerializationWarning: variable 'agc1' has multiple fill values {1e+35, -9999.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /Users/bell/miniconda3/envs/py38/lib/python3.8/site-packages/xarray/conventions.py:523: SerializationWarning: variable 'agc2' has multiple fill values {1e+35, -9999.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /Users/bell/miniconda3/envs/py38/lib/python3.8/site-packages/xarray/conventions.py:523: SerializationWarning: variable 'agc3' has multiple fill values {1e+35, -9999.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(
# /Users/bell/miniconda3/envs/py38/lib/python3.8/site-packages/xarray/conventions.py:523: SerializationWarning: variable 'agc4' has multiple fill values {1e+35, -9999.0}, decoding all values to NaN.
#   new_vars[k] = decode_cf_variable(

# %%
adcp_rcm_depth = adcp_data.sel(depth=(rcm_data['depth'].median()), method="nearest").to_dataframe().droplevel(['latitude','longitude'])

# %%
#wrap the plot in image settings for visual appeal
# may be able to make this cleaner or just a preset
# copy is in the notebook examples
# %run '../../settings/mpl_plot_settings.py'

# %matplotlib inline
import matplotlib.dates as mdates
from matplotlib.dates import YearLocator, WeekdayLocator, MonthLocator, DayLocator, HourLocator, DateFormatter
import matplotlib.ticker as ticker


fig, ax = plt.subplots(2,figsize=(24, 8),sharex=True)
ax[0].plot(rcm_data.index,rcm_data.ucomp_current,'k--',label='rcm U-Comp')
ax[1].plot(rcm_data.index,rcm_data.vcomp_current,'k--',label='rcm V-Comp')
ax[0].plot(adcp_rcm_depth.index,adcp_rcm_depth.ucomp_current,color='r',linewidth=1,label='ADCP U-Comp')
ax[1].plot(adcp_rcm_depth.index,adcp_rcm_depth.vcomp_current,color='b',linewidth=1,label='ADCP V-Comp')


ax[0].legend()
ax[1].legend()

xfmt = mdates.DateFormatter('%d-%b')
ax[1].xaxis.set_major_locator(DayLocator(bymonthday=1))
ax[1].xaxis.set_minor_locator(DayLocator(bymonthday=15))
ax[1].xaxis.set_minor_formatter(DateFormatter('%b %Y'))
ax[1].xaxis.set_major_formatter(DateFormatter(''))
ax[1].xaxis.set_tick_params(which='major', pad=3)
ax[1].xaxis.set_tick_params(which='minor', pad=5)
# Out:
# /Users/bell/Programs/ECOFOCI_Processing_Archive/settings/mpl_plot_settings.py:10: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-ticks')
