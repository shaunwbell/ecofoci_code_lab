# %% [markdown]
# # Table of Contents
#
# ## Summary
# - Please visit the [Summary](2_Summary.ipynb) for a description of the project.
#
# ## Explore a Vessel Class Prefix PP (PP-nnn)
# Individual Ships (nnn) are available in each vessel class exploration as well as an aggregate of each vessel class.  These explorations are identified prefixes from FOSDIC records.  Initial explorations used R3 records to make these plots.
#
# Some Prefixes are clearly invalid (non-numeric) while others appear valid but have minimal ships/samples to identify, and others only have a single sample or two and may be improperly encoded.  All but the clearly invalid prefixes and minimal simples (<10) are shown below:
#
# - '01' [ICOADS_GeoViews_pre01.ipynb](ICOADS_GeoViews_pre01.ipynb)
# - '02' [ICOADS_GeoViews_pre02.ipynb](ICOADS_GeoViews_pre02.ipynb)
# - '03' [ICOADS_GeoViews_pre03.ipynb](ICOADS_GeoViews_pre03.ipynb)
# - '06' [ICOADS_GeoViews_pre06.ipynb](ICOADS_GeoViews_pre06.ipynb)
# - '07' [ICOADS_GeoViews_pre07.ipynb](ICOADS_GeoViews_pre07.ipynb)
# - '08' [ICOADS_GeoViews_pre08.ipynb](ICOADS_GeoViews_pre08.ipynb)
# - '09' [ICOADS_GeoViews_pre09.ipynb](ICOADS_GeoViews_pre09.ipynb)
# - '10' [ICOADS_GeoViews_pre10.ipynb](ICOADS_GeoViews_pre10.ipynb)
# - '12' [ICOADS_GeoViews_pre12.ipynb](ICOADS_GeoViews_pre12.ipynb) - global temp coloring not available
# - '13' [ICOADS_GeoViews_pre13.ipynb](ICOADS_GeoViews_pre13.ipynb) - Class and/or Vessel wasn't identified
# - '14' [ICOADS_GeoViews_pre14.ipynb](ICOADS_GeoViews_pre14.ipynb) - global temp coloring not available?
# - '15' [ICOADS_GeoViews_pre15.ipynb](ICOADS_GeoViews_pre15.ipynb)
# - '16' [ICOADS_GeoViews_pre16.ipynb](ICOADS_GeoViews_pre16.ipynb)
# - '17' [ICOADS_GeoViews_pre17.ipynb](ICOADS_GeoViews_pre17.ipynb) - Class and/or Vessel wasn't identified
# - '18' [ICOADS_GeoViews_pre18.ipynb](ICOADS_GeoViews_pre18.ipynb)
# - '19' [ICOADS_GeoViews_pre19.ipynb](ICOADS_GeoViews_pre19.ipynb) - Class and/or Vessel wasn't identified
# - '20' [ICOADS_GeoViews_pre20.ipynb](ICOADS_GeoViews_pre20.ipynb)
# - '21' [ICOADS_GeoViews_pre21.ipynb](ICOADS_GeoViews_pre21.ipynb)
# - '22' [ICOADS_GeoViews_pre22.ipynb](ICOADS_GeoViews_pre22.ipynb)
# - '23' [ICOADS_GeoViews_pre23.ipynb](ICOADS_GeoViews_pre23.ipynb) - Class and/or Vessel wasn't identified, no SST data
# - '25' [ICOADS_GeoViews_pre25.ipynb](ICOADS_GeoViews_pre25.ipynb) - Class and/or Vessel wasn't identified
# - '26' [ICOADS_GeoViews_pre26.ipynb](ICOADS_GeoViews_pre26.ipynb) - Class and/or Vessel wasn't identified
# - '27' [ICOADS_GeoViews_pre27.ipynb](ICOADS_GeoViews_pre27.ipynb) - Class and/or Vessel wasn't identified
# - '28' [ICOADS_GeoViews_pre28.ipynb](ICOADS_GeoViews_pre28.ipynb) - Class and/or Vessel wasn't identified
# - '29' [ICOADS_GeoViews_pre29.ipynb](ICOADS_GeoViews_pre29.ipynb) - Class and/or Vessel wasn't identified
# - '30' [ICOADS_GeoViews_pre30.ipynb](ICOADS_GeoViews_pre30.ipynb) - Class and/or Vessel wasn't identified
# - '31' [ICOADS_GeoViews_pre31.ipynb](ICOADS_GeoViews_pre31.ipynb)
# - '32' [ICOADS_GeoViews_pre32.ipynb](ICOADS_GeoViews_pre32.ipynb)
# - '33' [ICOADS_GeoViews_pre33.ipynb](ICOADS_GeoViews_pre33.ipynb)
# - '34' [ICOADS_GeoViews_pre34.ipynb](ICOADS_GeoViews_pre34.ipynb) - Class and/or Vessel wasn't identified
# - '35' [ICOADS_GeoViews_pre35.ipynb](ICOADS_GeoViews_pre35.ipynb)
# - '37' [ICOADS_GeoViews_pre37.ipynb](ICOADS_GeoViews_pre37.ipynb)
# - '38' [ICOADS_GeoViews_pre38.ipynb](ICOADS_GeoViews_pre38.ipynb) - Class and/or Vessel wasn't identified
# - '39' [ICOADS_GeoViews_pre39.ipynb](ICOADS_GeoViews_pre39.ipynb)
# - '40' [ICOADS_GeoViews_pre40.ipynb](ICOADS_GeoViews_pre40.ipynb) - all ships map error - only ship by ship available
# - '41' [ICOADS_GeoViews_pre41.ipynb](ICOADS_GeoViews_pre41.ipynb)
# - '42' [ICOADS_GeoViews_pre42.ipynb](ICOADS_GeoViews_pre42.ipynb)
# - '43' [ICOADS_GeoViews_pre43.ipynb](ICOADS_GeoViews_pre43.ipynb) - all ships map error - only ship by ship available
# - '44' [ICOADS_GeoViews_pre44.ipynb](ICOADS_GeoViews_pre44.ipynb)
# - '45' [ICOADS_GeoViews_pre45.ipynb](ICOADS_GeoViews_pre45.ipynb)
# - '46' [ICOADS_GeoViews_pre46.ipynb](ICOADS_GeoViews_pre46.ipynb)
# - '47' [ICOADS_GeoViews_pre47.ipynb](ICOADS_GeoViews_pre47.ipynb) - Class and/or Vessel wasn't identified
# - '48' [ICOADS_GeoViews_pre48.ipynb](ICOADS_GeoViews_pre48.ipynb)
# - '49' [ICOADS_GeoViews_pre49.ipynb](ICOADS_GeoViews_pre49.ipynb)
# - '50' [ICOADS_GeoViews_pre50.ipynb](ICOADS_GeoViews_pre50.ipynb)
# - '51' [ICOADS_GeoViews_pre51.ipynb](ICOADS_GeoViews_pre51.ipynb)
# - '52' [ICOADS_GeoViews_pre52.ipynb](ICOADS_GeoViews_pre52.ipynb)
# - '54' [ICOADS_GeoViews_pre54.ipynb](ICOADS_GeoViews_pre54.ipynb)
# - '55' [ICOADS_GeoViews_pre55.ipynb](ICOADS_GeoViews_pre55.ipynb)
# - '56' [ICOADS_GeoViews_pre56.ipynb](ICOADS_GeoViews_pre56.ipynb)
# - '58' [ICOADS_GeoViews_pre58.ipynb](ICOADS_GeoViews_pre58.ipynb)
# - '59' [ICOADS_GeoViews_pre59.ipynb](ICOADS_GeoViews_pre59.ipynb)
# - '60' [ICOADS_GeoViews_pre60.ipynb](ICOADS_GeoViews_pre60.ipynb)
# - '61' [ICOADS_GeoViews_pre61.ipynb](ICOADS_GeoViews_pre61.ipynb)
# - '62' [ICOADS_GeoViews_pre62.ipynb](ICOADS_GeoViews_pre62.ipynb) - all ships map error - only ship by ship available
# - '65' [ICOADS_GeoViews_pre65.ipynb](ICOADS_GeoViews_pre65.ipynb)
# - '68' [ICOADS_GeoViews_pre68.ipynb](ICOADS_GeoViews_pre68.ipynb)
# - '71' [ICOADS_GeoViews_pre71.ipynb](ICOADS_GeoViews_pre71.ipynb) - Class and/or Vessel wasn't identified, no SST data
# - '76' [ICOADS_GeoViews_pre76.ipynb](ICOADS_GeoViews_pre76.ipynb)
# - '77' [ICOADS_GeoViews_pre77.ipynb](ICOADS_GeoViews_pre77.ipynb)
# - '78' [ICOADS_GeoViews_pre78.ipynb](ICOADS_GeoViews_pre78.ipynb)
# - '81' [ICOADS_GeoViews_pre81.ipynb](ICOADS_GeoViews_pre81.ipynb)
# - '82' [ICOADS_GeoViews_pre82.ipynb](ICOADS_GeoViews_pre82.ipynb) - Class and/or Vessel wasn't identified
# - '84' [ICOADS_GeoViews_pre84.ipynb](ICOADS_GeoViews_pre84.ipynb)
# - '85' [ICOADS_GeoViews_pre85.ipynb](ICOADS_GeoViews_pre85.ipynb) - Class and/or Vessel wasn't identified
# - '86' [ICOADS_GeoViews_pre86.ipynb](ICOADS_GeoViews_pre86.ipynb)
# - '88' [ICOADS_GeoViews_pre88.ipynb](ICOADS_GeoViews_pre88.ipynb)
# - '89' [ICOADS_GeoViews_pre89.ipynb](ICOADS_GeoViews_pre89.ipynb)
# - '90' [ICOADS_GeoViews_pre90.ipynb](ICOADS_GeoViews_pre90.ipynb) - Class and/or Vessel wasn't identified
# - '91' [ICOADS_GeoViews_pre91.ipynb](ICOADS_GeoViews_pre91.ipynb) - Class and/or Vessel wasn't identified
# - '94' [ICOADS_GeoViews_pre94.ipynb](ICOADS_GeoViews_pre94.ipynb)
# - '95' [ICOADS_GeoViews_pre95.ipynb](ICOADS_GeoViews_pre95.ipynb)
# - '96' [ICOADS_GeoViews_pre96.ipynb](ICOADS_GeoViews_pre96.ipynb)
# - '97' [ICOADS_GeoViews_pre97.ipynb](ICOADS_GeoViews_pre97.ipynb)
# - '98' [ICOADS_GeoViews_pre98.ipynb](ICOADS_GeoViews_pre98.ipynb)
#
# ## FOSDIC Transcoding
# - routines to convert the FOSDIC decks used to CSV files for exploration - [link](3a_Deck195_FOSDIC_Decoding.ipynb)
# - Significant historical discussion for these datasets exists on the ICOADS pages.

# %% [markdown]
# ## FOSDIC Deck 195 Merged Dataset with Deck 195 Vessel Meta Information
#
# - CSV file containing entire original FOSDIC record, some parsing (geolocation, time, temperatures) and un parsed sub records (seastate and present weather fields) merged with appropriate vessel/hull Identification and links to online information and repositories
#
# [relative link to file](../data/MetaDataRediscovery/FOSDICpDeck195ID.csv) or [direct link to file](https://github.com/shaunwbell/ecofoci_code_lab/tree/main/jupyterbook/content/code_gallery)
